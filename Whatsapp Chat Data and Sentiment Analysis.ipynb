# %% [markdown]
# ## Install required packages

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (2.12.1)
# Requirement already satisfied: typing-extensions>=4.7.0 in /Users/aarushi/Library/Python/3.9/lib/python/site-packages (from emoji) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dateparser
# Out:
# Requirement already satisfied: dateparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.2.0)
# Requirement already satisfied: python-dateutil in /Users/aarushi/Library/Python/3.9/lib/python/site-packages (from dateparser) (2.9.0.post0)
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dateparser) (2024.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dateparser) (2024.7.24)
# Requirement already satisfied: tzlocal in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dateparser) (5.2)
# Requirement already satisfied: six>=1.5 in /Users/aarushi/Library/Python/3.9/lib/python/site-packages (from python-dateutil->dateparser) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jovian
# Out:
# Requirement already satisfied: jovian in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.47)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jovian) (2.32.3)
# Requirement already satisfied: uuid in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jovian) (1.30)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jovian) (6.0.2)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jovian) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->jovian) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->jovian) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->jovian) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->jovian) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import all required packages for the project

# %%
import re

# %%
import matplotlib.pyplot as plot

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import calendar

# %%
import datetime as dt

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
import emoji

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
import random

# %%
from textblob import TextBlob

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.decomposition import NMF

# %%
sns.set(rc={'figure.figsize':(14,6)})

# %% [markdown]
# # Data Cleaning

# %%
def startswithDate(s):
    pattern='^([0-2][0-9]|(3)[0-1])(\/)(((0)[0-9])|((1)[0-2]))(\/)(\d{2}|\d{4}), ([0-9][0-9]):([0-9][0-9]) -'
    result=re.match(pattern,s)
    if result:
        return True
    return False

# %%
def startswithAuthor(s):
    patterns=['([\w]+):', # First Name
              '([\w]+[\s]+[\w]+):', # First Name + Last Name
             '([\w]+[\s]+[\w]+[\s]+[\w]+):',  # First Name+ Middle Name + Last Name
             '^(\+\d{1,2}\s)?\(?\d{3}\) ((\(\d{3}\) ?)|(\d{3}-))?\d{3}-\d{4}:',  #Mobile Number(US)
             '([+]\d{2} \d{4} \d{6}):',  # Mobile Number (Europe)
           '([+]\d{3} \d{3} \d{6})'  # Mobile Number (Uganda)
             ]
    pattern='^'+'|'.join(patterns)
    result=re.match(pattern,s)
    if result:
        return True
    return False

# %%
def getDataPoint(line):
    splitLine=line.split(' - ') #splitLine=['18/06/2021, 22:47','Loki: Why do you have two numbers, Arsalan?']
    dateTime=splitLine[0] # '18/06/2021, 22:47'
    message=' '.join(splitLine[1:]) #'Loki: Why do you have two numbers, Arsalan?'
    if startswithAuthor(message): #True
        splitmessage=message.split(': ') #splitmessage=['Loki','Why do you have two numbers, Arsalan?']
        author=splitmessage[0] #author='Loki'
        message=" ".join(splitmessage[1:]) # message='Why do you have two numbers, Arsalan?''
    else:
        author=None
    return dateTime,author,message

# %%
parsedChat=[]
convoPath='./WhatsappChat.txt'
with open(convoPath,encoding='utf-8') as fp:
    fp.readline
    messagebuffer=[]
    dateTime,author=None,None
    
    while True:
        line=fp.readline()
        if not line:
            break
        line=line.strip()
        if startswithDate(line):
            if len(messagebuffer)>0:
                parsedChat.append([dateTime,author," ".join(messagebuffer)])
                messagebuffer.clear()
                dateTime,author,message=getDataPoint(line)
                messagebuffer.append(message)
            else:
                messagebuffer.append(line)

# %%
parsedChat
# Out:
# [[None, None, '26/12/2017, 12:28 - Pauline: Lena and Pauline available✔'],
#  ['26/12/2017, 15:58',
#   'Joanna',
#   'Testing 3-5 outdoor venues by night today and will advise after camera man has shared.'],
#  ['26/12/2017, 22:45', 'Joanna', '<Media omitted>'],
#  ['28/12/2017, 21:14', 'Micheal', 'It will happen to you'],
#  ['28/12/2017, 21:39', '+256 792 754083', 'See yourself'],
#  ['28/12/2017, 23:12',
#   'Beth',
#   "23/12/2017, 23:42:10 \u202a+256\xa0701\xa0839948\u202c BEWARE. IT'S SNAKE SEASON!!!"],
#  ['29/12/2017, 15:27', None, 'Tina, Kerbi: <Media omitted>'],
#  ['29/12/2017, 15:36', 'Micheal', "Tina ng'okaye"],
#  ['29/12/2017, 21:43',
#   'Aunt Dora',
#   'For this coming new year I am not wishing anybody anything:'],
#  ['29/12/2017, 22:17', 'Aunt Dora', '<Media omitted>'],
#  ['30/12/2017, 18:09', 'Beth', '<Media omitted>'],
#  ['30/12/2017, 21:33',
#   'Aunt Dora',
#   'Am taking your orders. 2018 is anticipated to get tough expenditure wise'],
#  ['30/12/2017, 21:33', 'Aunt Dora', '<Media omitted>'],
#  ['30/12/2017, 21:33', 'Aunt Dora', '<Media omitted>'],
#  ['31/12/2017, 04:29', 'Aunt Dora', '<Media omitted>'],
#  ['31/12/2017, 13:52',
#   'Joanna',
#   'If a pregnant woman give birth to two babies, the first one comes out at 11:58pm 31st December 2017, and the second baby comes out at 12.05am of 1st January 2018.QUESTION:1. Are they twins? 2.. Are they age mates?3.  Which year will they claim? 4 In which month  will they celebrate their birthday?'],
#  ['31/12/2017, 13:58', None, 'Tina, Kerbi: Oxymoron🤦🏾\u200d♀'],
#  ['31/12/2017, 14:01', 'Beth', 'This happened last year'],
#  ['31/12/2017, 14:24', '+44 7525 475883', '<Media omitted>'],
#  ['31/12/2017, 15:15', 'Kate', 'That solar panel👀 wowo'],
#  ['31/12/2017, 18:59',
#   None,
#   'Tina, Kerbi: I wish u all a very prosperus and life full 2018. Tina Chribi'],
#  ['31/12/2017, 19:23', '+256 792 754083', 'Totukooya'],
#  ['31/12/2017, 19:23',
#   '+256 792 754083',
#   'Happy new year to this wonderful family.. love you guys 🤙🤙'],
#  ['31/12/2017, 19:49', 'Micheal', '<Media omitted>'],
#  ['31/12/2017, 19:50', 'Anna Christine', "😂😂😂 u don't want a new u?"],
#  ['31/12/2017, 19:51', None, 'Tina, Kerbi: Noza kubagye!!'],
#  ['31/12/2017, 19:59', 'Micheal', 'Most of us stay the same ...'],
#  ['31/12/2017, 20:00', 'Anna Christine', 'A new day has come...🎵🎶🎼'],
#  ['31/12/2017, 20:01',
#   'Micheal',
#   'Of course ... it lasts 2 months yet peeps are doing the same stuff as before yet yelling new everything'],
#  ['31/12/2017, 20:01',
#   'Anna Christine',
#   'Banange...tuleka nawe...human nature'],
#  ['31/12/2017, 21:25',
#   'Joanna',
#   "Hahaha I know what you're drinking! Where do I find you ?"],
#  ['31/12/2017, 22:28', 'Aunt Dora', 'A New Metal has been added to Chemistry'],
#  ['31/12/2017, 22:31', None, 'Tina, Kerbi: Hez fasting'],
#  ['31/12/2017, 22:53', 'Joanna', 'Happy new year and wappi to the answer'],
#  ['31/12/2017, 23:11', 'Micheal', "I'm following him on the fast"],
#  ['31/12/2017, 23:49',
#   'Joanna',
#   '😂😂😂💦💦💦dead God is seeing you my hanging tyts'],
#  ['01/01/2018, 00:06',
#   'Joanna',
#   'Happy new year. The first when Mtn is civilized'],
#  ['01/01/2018, 00:09', 'TJ Musiitwa', 'Civilized how?'],
#  ['01/01/2018, 00:10', 'Joanna', 'We remain in touch'],
#  ['01/01/2018, 00:11', 'Ben', 'Happy New Year people ... Jah Bless'],
#  ['01/01/2018, 00:12', 'Anthony Busulwa', 'Happy New year everyone.'],
#  ['01/01/2018, 00:15', '+1 (647) 704-2525', 'Happy new year!!!'],
#  ['01/01/2018, 00:39', 'Patsy', 'happy new year loves'],
#  ['01/01/2018, 01:00', 'Irene Nakalembe', 'Happy new year fam'],
#  ['01/01/2018, 01:21', 'Micheal', 'A HAppy new year to.you all'],
#  ['01/01/2018, 01:32', 'Lena', 'Happy New year!'],
#  ['01/01/2018, 01:47', 'Olivia Namulindwa', '🎊Happy New Year!!!!🎉'],
#  ['01/01/2018, 09:46', 'Lawrence Kibuuka', 'Wishing you a  prosperous and a'],
#  ['01/01/2018, 10:36',
#   'Joanna',
#   "Happy New Year! Wish each and everyone of you God's abundant blessings. May good things overwhelm you."],
#  ['01/01/2018, 13:16', 'Anna Christine', 'Thank you Jo; and to you too'],
#  ['01/01/2018, 13:17',
#   'Anna Christine',
#   'Happy new year fam! May all your hearts desires be realised!'],
#  ['01/01/2018, 13:17', 'Anna Christine', 'Lol, si byampaka Lau!'],
#  ['01/01/2018, 20:55',
#   'Aunt Dora',
#   'Thanks love. I will keep it, just be faithful and don’t send it again every year cos I also get tied of reading history'],
#  ['01/01/2018, 20:59', 'Joanna', 'Hahahahaha 😂😂😂😂💦💦👆🏽👍🏽'],
#  ['01/01/2018, 21:15', 'Lawrence Kibuuka', '😂😂'],
#  ['02/01/2018, 19:17', 'TJ Musiitwa', '<Media omitted>'],
#  ['02/01/2018, 19:39', 'Lena', 'Man went to Nigeria!  They calmed him down'],
#  ['03/01/2018, 16:32',
#   'Aunt Dora',
#   '*Dearly, if you do not work hard this 2018, you will keep on forwarding long messages to 10 people so that a miracle can happen in 10 minutes..*'],
#  ['03/01/2018, 16:32', 'Aunt Dora', '<Media omitted>'],
#  ['03/01/2018, 16:57', 'Aunt Dora', '<Media omitted>'],
#  ['03/01/2018, 17:11', 'Lena', 'Genius!'],
#  ['03/01/2018, 23:18',
#   'Joanna',
#   'If you thought entering 2018 was great and worthy celebrating, think again 🤔!  Have you noticed the big red question marks looming over this year?!!'],
#  ['03/01/2018, 23:18', 'Joanna', 'MISSING PERSON!'],
#  ['04/01/2018, 09:40', 'Ben', '<Media omitted>'],
#  ['04/01/2018, 09:40', 'Lena', '😂😂😂'],
#  ['04/01/2018, 09:41', 'Irene Nakalembe', '😂😂😂'],
#  ['04/01/2018, 17:12',
#   'Joanna',
#   'His body was found yesterday afternoon in Kajjansi. Horrible tragedy. The police are on the case'],
#  ['04/01/2018, 17:14', None, 'Tina, Kerbi: Ok detective'],
#  ['04/01/2018, 17:14', 'Joanna', 'Poor guy may his soul rest in peace'],
#  ['04/01/2018, 17:34',
#   'Fina',
#   "That's sad. Really sad. May he rest in peace bambi"],
#  ['04/01/2018, 18:11',
#   'Aunt Dora',
#   'So sad. Oh God change the hearts of the wrong doers and rest his soul peace.'],
#  ['04/01/2018, 18:27', 'Kate', 'Really sad'],
#  ['04/01/2018, 20:30', 'Aunt Dora', "*BANK DETAILS' MADNESS.*"],
#  ['04/01/2018, 20:32', 'Aunt Dora', '<Media omitted>'],
#  ['04/01/2018, 20:54',
#   'Aunt Dora',
#   '"When your salary comes in time, you eat chicken. As the salary reduces you eat products of Chicken (Eggs) and subsequently you begin to eat chicken\'s food, (maize and millet), and finally, when salary is finished, you become chicken itself, spending your time walking around just looking for what to eat"!_'],
#  ['04/01/2018, 20:55', 'Lena', 'This message was deleted'],
#  ['04/01/2018, 21:04',
#   'Aunt Dora',
#   'Dubai  This passenger was caught in airport, he told custom officers that he was helping a friend to carry two  brand new iphones to give to designated person. He was sentenced to death penalty. Never never "help" to carry any item at all. Even from your friends!!'],
#  ['04/01/2018, 21:04', 'Aunt Dora', '<Media omitted>'],
#  ['04/01/2018, 21:04', 'Aunt Dora', '<Media omitted>'],
#  ['05/01/2018, 20:08', 'Joanna', 'Hey all'],
#  ['05/01/2018, 20:08', 'Joanna', "We're still on for Sunday"],
#  ['05/01/2018, 20:08', 'Joanna', 'Please have lunch at yours'],
#  ['05/01/2018, 20:08', 'Joanna', "We'll have the shoot at 3:00pm"],
#  ['05/01/2018, 20:08', 'Patsy', 'ok'],
#  ['05/01/2018, 20:09',
#   'Joanna',
#   "Everyone attempting to send regrets or apologies, I love you but not accepted. We've had some time for this date, all the new proggie arising is not accepted. Please I begoooooo, it's even at 3:00pm to allow movement time"],
#  ['05/01/2018, 20:10', 'TJ Musiitwa', 'Please resend the *where*'],
#  ['05/01/2018, 20:11',
#   'Joanna',
#   "We'll have lights catch up drinks and bites on site and slight celebration of recent babies like Solome of 2nd if you have companions that have driven to the venue, they'll be well taken care of in the meals. Any time to meet is 🌟🙌🏽👍🏽👌🏽👌🏽"],
#  ['05/01/2018, 20:11', 'Joanna', '*light not lights'],
#  ['05/01/2018, 20:12',
#   'Joanna',
#   "Okay I'll send tomorrow. If by then Tony Agaba and Tina B haven't by then.  😘"],
#  ['05/01/2018, 20:22',
#   'Joanna',
#   "Anyone rereading, here's our sweet repost 👇🏾"],
#  ['05/01/2018, 21:14',
#   None,
#   'Tina, Kerbi: In between Fresh cuts and fuelex therez a turning on yo left fm kla, going to seguku. Drive straiight fo abt a kilometer (ignoring the Agaba close) until u see a poster on yo left saying-PIONEER VILLAZ'],
#  ['05/01/2018, 21:14', None, 'Tina, Kerbi: Gawa u can pitch in....😊'],
#  ['05/01/2018, 21:27', 'Lena', 'Ahhhh!'],
#  ['05/01/2018, 21:27', 'Lena', 'Drop a pin!'],
#  ['05/01/2018, 21:28',
#   'Joanna',
#   'Tony can do that or that first person to get there'],
#  ['05/01/2018, 21:28', 'Joanna', 'Basically peku Sunday'],
#  ['05/01/2018, 21:29', 'Joanna', 'Azawyz thanks Chribi'],
#  ['05/01/2018, 21:30',
#   'Joanna',
#   "Turning on your right if you're coming from kla"],
#  ['05/01/2018, 21:31',
#   'Joanna',
#   'In between Fresh cuts and fuelex therez a turning on yo right fm kla, going to seguku. Drive straight for abt a kilometer, skip the tee junction and continueeeeeeeer (ignoring the Agaba close) until u see a poster on yo left saying-PIONEER VILLAZ'],
#  ['05/01/2018, 21:31', 'Joanna', 'Pin to be dropped'],
#  ['05/01/2018, 21:51', 'TJ Musiitwa', 'We shall be lost some of us...'],
#  ['05/01/2018, 21:57', 'Joanna', "I'll help with directions"],
#  ['05/01/2018, 21:58',
#   'Joanna',
#   "I'll also be in Rubaga to set off with some pipo"],
#  ['05/01/2018, 22:09', 'TJ Musiitwa', 'Awesome'],
#  ['06/01/2018, 00:18',
#   '+256 792 754083',
#   'location https://maps.google.com/?q=0.2317640781402588,32.52946090698242'],
#  ['06/01/2018, 01:09', 'Joanna', 'Thanks Tony'],
#  ['06/01/2018, 01:10', 'Joanna', 'Lena seen it? Thanks T🌟'],
#  ['06/01/2018, 08:56', 'Lena', 'Thank you!!'],
#  ['06/01/2018, 10:14', 'Pauline', '<Media omitted>'],
#  ['06/01/2018, 10:20', 'Ben', 'Tubidemu byetwaziina kuluuli...'],
#  ['06/01/2018, 11:40', None, 'Tina, Kerbi: Kutama...'],
#  ['06/01/2018, 11:47', 'Micheal', '😂🤣'],
#  ['06/01/2018, 14:46', 'Joanna', 'Jambo to those with mbs;'],
#  ['06/01/2018, 15:01', 'Ben', '<Media omitted>'],
#  ['06/01/2018, 15:07', 'Lena', '😂😂😂😂😂😂😂😂'],
#  ['06/01/2018, 16:12',
#   'Joanna',
#   "👏🏽👏🏽👏🏽👏🏽love you Godi can't wait to see you tomorrow. Been a while."],
#  ['06/01/2018, 17:50',
#   'Olivia Namulindwa',
#   '🎉Happy Birthday Uncle Vicky!!! ❤'],
#  ['06/01/2018, 17:51', 'Anna Christine', '❤ Olivia'],
#  ['06/01/2018, 17:52',
#   'Joanna',
#   "Bambi it's true... Neera ANNA please relay for us too. Or Lena and Paula.... Happy Basde"],
#  ['06/01/2018, 17:52', 'Joanna', 'Thanks Livy'],
#  ['06/01/2018, 17:52', 'Anna Christine', 'Will do'],
#  ['06/01/2018, 18:16', 'Irene Nakalembe', 'Happy happy birthday Incle Vicky'],
#  ['06/01/2018, 18:52', 'Anna Christine', 'Thanks hun'],
#  ['06/01/2018, 20:02',
#   'Aunt Dora',
#   "If you hadn't yet found reason to be grateful every single moment, watch this man. 👇🏾"],
#  ['06/01/2018, 20:02', 'Aunt Dora', '<Media omitted>'],
#  ['06/01/2018, 21:20', 'Kate', 'Oh my. Oh my'],
#  ['06/01/2018, 22:22', 'Aunt Dora', 'Renewing vows'],
#  ['06/01/2018, 22:22', 'Aunt Dora', '<Media omitted>'],
#  ['06/01/2018, 22:22', 'Aunt Dora', '<Media omitted>'],
#  ['06/01/2018, 22:22', 'Aunt Dora', '<Media omitted>'],
#  ['07/01/2018, 02:35', 'Aunt Dora', '<Media omitted>'],
#  ['07/01/2018, 13:58',
#   'Joanna',
#   'Hello people is everyone ok with directions? Should I wait for anyone to follow me along the way like in kibuye ?'],
#  ['07/01/2018, 14:06',
#   'Anna Christine',
#   "Will call u on our way.  Just to clarify,  is it before fuelex I'd coming from kla?"],
#  ['07/01/2018, 15:19',
#   'Lawrence Kibuuka',
#   'The road exactly opposite fresh cuts before fuelex'],
#  ['07/01/2018, 15:20', 'Anna Christine', 'K, thanks'],
#  ['07/01/2018, 15:46', 'Fina', 'Lost'],
#  ['07/01/2018, 15:46', 'Fina', 'On seguku road'],
#  ['07/01/2018, 15:46', 'Fina', "But don't see pioneer"],
#  ['07/01/2018, 15:46', '+256 792 754083', '<Media omitted>'],
#  ['07/01/2018, 15:50', 'Joanna', 'Let me call you'],
#  ['07/01/2018, 15:50', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 15:53',
#   'Joanna',
#   'Jose please follow the Katale miracle centre road and curve with road, call tony when the Tarmac starts or Lawrence. They will stand outside the gate so you can see them.'],
#  ['07/01/2018, 15:53', 'Joanna', "I'm charging my phone"],
#  ['07/01/2018, 15:53', 'Lena', 'Yeah tell Lawrence to stand outside'],
#  ['07/01/2018, 16:23', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:39', 'Joanna', 'Karen & Juni. Waiting for you to start'],
#  ['07/01/2018, 16:39', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:40', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:40', 'Joanna', 'Julie & Tina catch up'],
#  ['07/01/2018, 16:40', '+1 (647) 704-2525', 'Eh mama 😢'],
#  ['07/01/2018, 16:41', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:43', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:45', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:47', 'Junior', 'We are approaching fuelex'],
#  ['07/01/2018, 16:48', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:48', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:49', 'Joanna', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 16:52', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 18:24', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 18:53',
#   'Olivia Namulindwa',
#   'Loving the beautiful pictures!!❤😍'],
#  ['07/01/2018, 19:09', 'Elsie Mulo', '<Media omitted>'],
#  ['07/01/2018, 19:09', 'Elsie Mulo', '<Media omitted>'],
#  ['07/01/2018, 19:09', 'Elsie Mulo', '<Media omitted>'],
#  ['07/01/2018, 19:09', 'Elsie Mulo', '<Media omitted>'],
#  ['07/01/2018, 19:09', 'Elsie Mulo', '<Media omitted>'],
#  ['07/01/2018, 19:10', '+1 (647) 704-2525', '😍😍😍'],
#  ['07/01/2018, 19:10', 'Elsie Mulo', '<Media omitted>'],
#  ['07/01/2018, 19:41', 'Irene Nakalembe', 'But family we love u'],
#  ['07/01/2018, 19:44', 'Fina', '<Media omitted>'],
#  ['07/01/2018, 19:47',
#   'Irene Nakalembe',
#   'Every one needs a Joanna in their lives u truly r the make it happen queen!!! I admire u'],
#  ['07/01/2018, 20:00', 'Fina', 'True that Irene. Her energy alone..'],
#  ['07/01/2018, 20:19',
#   'Anna Christine',
#   'Totally! Joanna is truly one of a kind awesome'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:19', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 21:27', 'Micheal', 'Asante saana👌🏿👌🏿👌🏿👌🏿👌🏿'],
#  ['07/01/2018, 21:39',
#   'Joanna',
#   'I love you everyone so much! And I love you beyond words can say'],
#  ['07/01/2018, 21:52', 'Fina', 'Thank you Joanna for organizing'],
#  ['07/01/2018, 22:01', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:01', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:01', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:01', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:16',
#   '+256 792 754083',
#   'Thanks family.. truly fabulous .. was great hosting.. you all look amazing.. Pliz come back 😞😍😍😍'],
#  ['07/01/2018, 22:17', '+256 792 754083', 'When do we shoot in red 😜🤙🤙🤙'],
#  ['07/01/2018, 22:43', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:43', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:43', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:43', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:43', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:58', 'TJ Musiitwa', '<Media omitted>'],
#  ['07/01/2018, 22:59', 'Anna Christine', '👏👏👏👏'],
#  ['07/01/2018, 23:04', '+1 (647) 704-2525', 'Love love love ❤'],
#  ['07/01/2018, 23:12',
#   'Beth',
#   'Thank u all. It was lovely to see u all. I can see both teachers and parents raised discplined kids. We all adhered to the dress code'],
#  ['07/01/2018, 23:17', 'Julie Anna', '🤣🤣🤣thank uu'],
#  ['07/01/2018, 23:22', 'Irene Nakalembe', 'Awwww'],
#  ['07/01/2018, 23:29', 'Elsie Mulo', '😂😂😂😂'],
#  ['07/01/2018, 23:31', 'Elsie Mulo', 'Thank you so much Tony for hosting🤗'],
#  ['08/01/2018, 06:04', 'Tony Mulo', 'Everyone looks great. Fam is on point'],
#  ['08/01/2018, 08:22', 'Patsy', 'the first born trio'],
#  ['08/01/2018, 08:25',
#   'Anna Christine',
#   'Right on Patsy! Great minds sit together'],
#  ['08/01/2018, 08:26', 'Patsy', 'the “Originals”'],
#  ['08/01/2018, 11:00', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 11:00', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 11:00', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 11:00', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 11:00', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 11:08',
#   'Lena',
#   'thank you Michael, Thomas, Tony  and Joanna!!!!!'],
#  ['08/01/2018, 11:08', 'Anna Christine', 'Beautiful! Time to print.'],
#  ['08/01/2018, 11:09',
#   'Anna Christine',
#   'Yes Thomas thank you, and for all who made it'],
#  ['08/01/2018, 11:37', 'Lena', 'eehhh there were more back up camera people'],
#  ['08/01/2018, 11:37', 'Lena', 'Elsie, Joana and Jose, Good Job'],
#  ['08/01/2018, 11:38', 'Elsie Mulo', '🤗🤗🤗'],
#  ['08/01/2018, 11:54', None, "+60 17-247 2389 changed this group's icon"],
#  ['08/01/2018, 12:05', 'Micheal', 'The last ones standing....'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:05', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:08', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:08', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:31', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:50', None, "Pauline changed this group's icon"],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:32', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:37', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 12:37', 'Micheal', '<Media omitted>'],
#  ['08/01/2018, 14:43',
#   'Kate',
#   'Do you have look bad? Even in your thoughtfulness 🤥'],
#  ['08/01/2018, 14:43', 'Kate', 'Thanks lovies for hosting us'],
#  ['08/01/2018, 14:44',
#   'Kate',
#   'Blessing upon all who put effort to this day including attendees'],
#  ['08/01/2018, 14:44',
#   'Kate',
#   'I still see ka sweetie. Was nice seeing you..'],
#  ['08/01/2018, 14:45', 'Kate', 'Now this👌🏽'],
#  ['08/01/2018, 14:46', 'Kate', 'Priceless...'],
#  ['08/01/2018, 14:46', 'Kate', 'Thanks photographers. Thanks Michael.'],
#  ['08/01/2018, 14:46', 'Kate', 'Lovely memories'],
#  ['08/01/2018, 14:47', 'Lena', '☠⚱'],
#  ['08/01/2018, 14:48', 'Anna Christine', "She meant 'ever'..."],
#  ['08/01/2018, 14:49',
#   'Kate',
#   'Oops meant ever look bad. My phone is setting me up'],
#  ['08/01/2018, 14:49',
#   'Anna Christine',
#   "Wabula Katie that soda hangover next time it's the blue bottle....Michael is awake and alert as a whip!"],
#  ['08/01/2018, 14:49', 'Kate', 'Wama'],
#  ['08/01/2018, 14:50', 'Kate', 'Really. What colour of eyes?'],
#  ['08/01/2018, 14:50',
#   'Anna Christine',
#   "White enough to send pics in the morning. I hope he isn't visiting at Josie's"],
#  ['08/01/2018, 14:52',
#   'Kate',
#   '🤣🤣🤣🤣🤣 dont put ideas in his head. Had probably fprgotten. Monday 🤔🤔🤔🤔'],
#  ['08/01/2018, 14:53', 'Anna Christine', '😂😂😂 nanti he bees on leave'],
#  ['08/01/2018, 14:53', 'Kate', 'Oooohhh that explains'],
#  ['08/01/2018, 14:53', 'Beth', 'Bees 😂😂😂🤗🤗🤗'],
#  ['08/01/2018, 14:54', 'Anna Christine', '💁lol'],
#  ['08/01/2018, 14:55', 'Kate', 'Still mob cows to be earned 👀👀👀'],
#  ['08/01/2018, 14:55', 'Anna Christine', 'Tell them'],
#  ['08/01/2018, 14:56', 'Kate', "Would you use that 'word' in court?"],
#  ['08/01/2018, 15:00',
#   'Anna Christine',
#   "Well....that's why I run away from those old school, wig under wig wearing people"],
#  ['08/01/2018, 15:01', 'Beth', 'Hahahah'],
#  ['08/01/2018, 15:01', 'Beth', 'U are still part of them in away'],
#  ['08/01/2018, 15:56', 'Micheal', 'Very white'],
#  ['08/01/2018, 15:56', 'Micheal', "Found 13k emails..... didn't forget."],
#  ['08/01/2018, 15:56', 'Micheal', 'Enough for some.of us to borrow from 😜'],
#  ['08/01/2018, 16:00', 'Fina', '<Media omitted>'],
#  ['08/01/2018, 16:00', 'Fina', '🤣🤣'],
#  ['08/01/2018, 16:17', 'Micheal', 'It will.hAppen.to you'],
#  ['08/01/2018, 16:20',
#   '+256 792 754083',
#   '👏🏻👏🏻👏🏻👏🏻come back for the red photo shoot .. we shall have shooters “tekila, blue bomb, earthquake and fireworks “ plus no babies some people were arrested the entire time 😂😂😂😂🤸🏽\u200d♀🤸🏽\u200d♀🤸🏽\u200d♀'],
#  ['08/01/2018, 16:23', 'Joanna', 'Joanna sit properly'],
#  ['08/01/2018, 16:24', 'Joanna', "Me I'll be like you😂. On the fast🙈"],
#  ['08/01/2018, 16:29',
#   'Joanna',
#   '😂😂💦💦💦💦 these quadruplets; Feels like they stood in the same spot for a daylight & night pic.'],
#  ['08/01/2018, 16:30', 'Anna Christine', '😂😂😂😂seconded!'],
#  ['08/01/2018, 16:31', 'Pauline', '🤣🤣🤣🤣'],
#  ['08/01/2018, 16:31', 'Joanna', 'There are 2 pics like that day and night'],
#  ['08/01/2018, 16:31', 'Joanna', 'Say ngwe'],
#  ['08/01/2018, 16:48', 'Joanna', 'Kate your hair really grows fast!'],
#  ['08/01/2018, 16:51',
#   'Joanna',
#   'All the pics are really lovely. Thank you everyone.'],
#  ['08/01/2018, 16:51', 'Joanna', 'Hahahaha'],
#  ['08/01/2018, 17:24',
#   '+256 792 754083',
#   'I like u better the way u were 😍😍😍😍'],
#  ['08/01/2018, 17:50', 'Joanna', '<Media omitted>'],
#  ['08/01/2018, 22:06', 'Beth', '<Media omitted>'],
#  ['08/01/2018, 23:07', 'Joanna', '<Media omitted>'],
#  ['08/01/2018, 23:15', '+1 (647) 704-2525', 'That’s my twin 😍😍yass!!'],
#  ['08/01/2018, 23:15', 'Anna Christine', 'Hhahahhahaha'],
#  ['08/01/2018, 23:15', 'Anna Christine', 'Trying to represent Ade!'],
#  ['08/01/2018, 23:18',
#   'Fina',
#   'Still remember the ka beauty princess on sags stage😍😍'],
#  ['08/01/2018, 23:20',
#   'Anna Christine',
#   'Hahhahaha... Wabula Jose that ka red lipstick must have been the trick....thanks'],
#  ['08/01/2018, 23:21', 'Fina', 'No no. True story, lives on'],
#  ['08/01/2018, 23:22',
#   'Joanna',
#   "My family just has hot babes I stared yesterday kati what about those who are not related. I've forgiven them."],
#  ['08/01/2018, 23:23', 'Joanna', 'Then came Livia.... 🤕😷she grew up on me'],
#  ['08/01/2018, 23:24', 'Anna Christine', '😘'],
#  ['08/01/2018, 23:24', 'Anna Christine', 'Gwe... I tell you!'],
#  ['08/01/2018, 23:27',
#   'Irene Nakalembe',
#   'Yo that pic made me pause for a minute real deal u r all gorgeous'],
#  ['08/01/2018, 23:29', 'Anna Christine', 'Oh thank you! Credits to Thomas'],
#  ['08/01/2018, 23:42', 'Elsie Mulo', '🙈😂'],
#  ['08/01/2018, 23:45', 'Joanna', '<Media omitted>'],
#  ['08/01/2018, 23:46', 'Joanna', 'Very beautiful'],
#  ['08/01/2018, 23:47', 'Elsie Mulo', '😂😂otyo'],
#  ['09/01/2018, 00:03', 'Fina', 'Thenks 😊. Sula bulungi bebi'],
#  ['09/01/2018, 00:04', 'Joanna', '😂'],
#  ['09/01/2018, 02:47', 'Aunt Dora', '<Media omitted>'],
#  ['09/01/2018, 04:54',
#   'Aunt Dora',
#   'Bba dears, thanks a trillion for being so pretty handsome and beautiful.  There has never been a generational as lovely as that and I am sure there will never be. Your only competitors are Mr and Mrs Kawere the originals 👏🏽👏🏽👏🏽🙏🏽🙏🏽🙏🏽🙏🏽🙏🏽'],
#  ['09/01/2018, 07:16',
#   '+256 792 754083',
#   'We can have a shoot out and compare 😜😜😉😉👏🏻👏🏻👏🏻'],
#  ['09/01/2018, 07:27', 'Joanna', '😂'],
#  ['09/01/2018, 16:01', 'Fina', '😍😍😍'],
#  ['09/01/2018, 16:20',
#   'Livia Livie',
#   "Joanna... I'm still the same😏 I think 😂"],
#  ['09/01/2018, 17:22', 'Joanna', 'So I sampled you all'],
#  ['09/01/2018, 17:22',
#   'Joanna',
#   'Put you on my profile status for whatsapp and man hits rushed up'],
#  ['09/01/2018, 17:23',
#   'Joanna',
#   'I deleted in fear 🙆🏽 and started again and left two! Eh! You guys just beed mboko!'],
#  ['09/01/2018, 17:56', 'Kate', '😅 kwekusobola'],
#  ['09/01/2018, 19:32', 'Beth', '<Media omitted>'],
#  ['09/01/2018, 22:20', None, 'Tina, Kerbi: Thomas hv u left yet?!'],
#  ['09/01/2018, 22:21',
#   'Anna Christine',
#   'Oh bonvoyage Thomas! Always a delight to be with you. Best wishes in all you do and come back sooner'],
#  ['09/01/2018, 22:33', 'Elsie Mulo', 'save travels Thomas 🤗'],
#  ['09/01/2018, 22:33', 'Elsie Mulo', 'safe*'],
#  ['09/01/2018, 22:36', 'Fina', 'selamat jalan Thomas'],
#  ['09/01/2018, 22:44', 'Joanna', "Oba I really think he's still around"],
#  ['09/01/2018, 22:48', 'Anna Christine', 'Supposed to live today'],
#  ['09/01/2018, 22:51', 'Joanna', "He forgot me not. He's about the 21st."],
#  ['09/01/2018, 22:52', 'Joanna', 'We have plans 😎'],
#  ['09/01/2018, 22:52', 'Anna Christine', 'Said tuesday'],
#  ['09/01/2018, 22:52',
#   'Livia Livie',
#   "He couldn't change the date on his ticket .. So he couldn't go today"],
#  ['09/01/2018, 22:54',
#   'Anna Christine',
#   'Oh Joanna u in business....thanks Livie'],
#  ['09/01/2018, 23:00', 'TJ Musiitwa', 'Haha where did that Malay come from'],
#  ['09/01/2018, 23:01',
#   'TJ Musiitwa',
#   'Yup still around till 21st as duly explained'],
#  ['09/01/2018, 23:01', None, 'Tina, Kerbi: Went then...'],
#  ['10/01/2018, 05:52', 'Aunt Dora', '<Media omitted>'],
#  ['10/01/2018, 08:55', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:56', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:56', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:56', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:56', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:56', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:56', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['10/01/2018, 08:57', 'Lawrence Kibuuka', 'Opps sorry'],
#  ['10/01/2018, 08:57', 'Lawrence Kibuuka', 'Morning 🏃🏃🏃'],
#  ['10/01/2018, 12:01', 'Ben', '<Media omitted>'],
#  ['10/01/2018, 12:01', 'Ben', 'Why we had a black out last night'],
#  ['10/01/2018, 12:08', 'Lena', '😂😂😂'],
#  ['10/01/2018, 13:49', 'Anna Christine', '😂😂😂😂😂😂😂'],
#  ['10/01/2018, 22:00', 'Aunt Dora', '<Media omitted>'],
#  ['10/01/2018, 22:09', 'Aunt Dora', '<Media omitted>'],
#  ['11/01/2018, 19:05', 'Aunt Dora', '<Media omitted>'],
#  ['11/01/2018, 19:05', 'Aunt Dora', '<Media omitted>'],
#  ['11/01/2018, 23:13', 'Joanna', '<Media omitted>'],
#  ['11/01/2018, 23:14',
#   'Joanna',
#   "Is it true that lent starts on Valentine's????? But riyale how about us and  😍🙆🏽🙆🏽🙆🏽🙆🏽"],
#  ['11/01/2018, 23:24', 'Micheal', "What don't you see👆🏼👆🏼👆🏼"],
#  ['11/01/2018, 23:24', 'Joanna', 'Eish! Sadness just'],
#  ['11/01/2018, 23:24',
#   'Joanna',
#   'So how does God expect creativity on such a day?'],
#  ['11/01/2018, 23:26',
#   'Micheal',
#   'why not live each day like that one? And not wait for once a year 🤷🏽\u200d♂'],
#  ['11/01/2018, 23:26',
#   'Joanna',
#   'I have started a hashtag, #Imawesomelyakawere'],
#  ['11/01/2018, 23:31', 'Anna Christine', 'Talk on it Michael'],
#  ['11/01/2018, 23:41', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['11/01/2018, 23:43', 'Joanna', 'It can be hectic shya nawe'],
#  ['11/01/2018, 23:43', 'Anna Christine', '😂😂😂😂😂😂😂'],
#  ['11/01/2018, 23:44',
#   'Anna Christine',
#   'Ok now u know...wine, dine and whisper on the 13th'],
#  ['11/01/2018, 23:45',
#   'Joanna',
#   'Hmh! Men should just walk straight headed in Jan! Tebampona'],
#  ['11/01/2018, 23:47',
#   'Joanna',
#   'Bosses should expect unwellness of all or any family member, teeth removal & body part checkups! Even id pickups Nira offices etc'],
#  ['12/01/2018, 10:03', '+256 776 584356 left', ''],
#  ['13/01/2018, 10:41',
#   'Lena',
#   'Back to the photo shoot why did Tony and Theo always stand together? 🤐🏃\u200d♀'],
#  ['13/01/2018, 12:16', 'Anna Christine', '💆🏽🤷🏽\u200d♀'],
#  ['13/01/2018, 14:11', 'Patsy', 'bro shit'],
#  ['13/01/2018, 14:12', 'Beth', '<Media omitted>'],
#  ['13/01/2018, 14:37', 'Fina', '🤣🤣🤣 bambi'],
#  ['13/01/2018, 15:54', None, 'Tina, Kerbi: Lol...'],
#  ['13/01/2018, 19:19',
#   'Aunt Dora',
#   '"There was a bird that lived in the desert, very sick, without feathers, nothing to eat, drink and shelter to live, cursing his life, day and night.'],
#  ['13/01/2018, 20:33', 'Anna Christine', 'Amen!'],
#  ['13/01/2018, 20:49', 'Fina', 'Thank You God for everything'],
#  ['13/01/2018, 23:20', 'Aunt Dora', '<Media omitted>'],
#  ['13/01/2018, 23:20', 'Aunt Dora', '<Media omitted>'],
#  ['14/01/2018, 12:04',
#   'Fina',
#   'Happy 40 years to Mr and Mrs Kibuuka. Congratulations the Kibuuka family here on behalf of your parents'],
#  ['14/01/2018, 12:49', 'Lena', 'Happy anniversary!!!'],
#  ['14/01/2018, 12:50',
#   'Anna Christine',
#   'Wow! Happy 40th anniversary Mr & Mrs.  Kibuuka!'],
#  ['14/01/2018, 13:20', 'Patsy', 'happy anniversary'],
#  ['14/01/2018, 13:52', 'Bengie', 'Happy anniversary  🤗🤗'],
#  ['14/01/2018, 14:15', 'Elsie Mulo', 'happy anniversary😊'],
#  ['14/01/2018, 14:18', 'Beth', 'Thanks people on there behalf'],
#  ['14/01/2018, 14:45', 'Joanna', 'Thank you Jose on their behalf....'],
#  ['14/01/2018, 14:49',
#   'Joanna',
#   "Thank you all, Patsy, Bengie, Elsie, Anna, Lena, thank you.... We had an amazing sermon this morning where the priest asked them to tell the crowd three things that each one loves and admires about the other over the time they've been married. Abange... Nenkulabira. When you're the kid you become shy as if you don't watch movies everyday. I just guess it's different when it's here and so U.G. It was humbling."],
#  ['14/01/2018, 14:49', 'Junior', 'Happy Anniversary'],
#  ['14/01/2018, 14:49', 'Anna Christine', '😂😂😂😂😂😂😂'],
#  ['14/01/2018, 14:50', 'Anna Christine', 'Aha,  tell us what they said'],
#  ['14/01/2018, 14:51',
#   'Joanna',
#   "I'm here enjoying the 56th day of January 😂💦💦over a polite lunch..... Ahead of the photoshoot one in February or some other day some time. 🙈hehe"],
#  ['14/01/2018, 14:57',
#   'Joanna',
#   "Dad (about mum) 1.Mulungi mu ndabika,mutiima ne mu mwoyo, 2.Ddiini and 3. Mukozi  she's hardworking"],
#  ['14/01/2018, 14:57', 'Anna Christine', '👏👏👏👏'],
#  ['14/01/2018, 14:58',
#   'Joanna',
#   'While one of the guys that spoke said the compete mu ddiini and that whatever the other has even the other has eg their ddiini competes.'],
#  ['14/01/2018, 14:59',
#   'Joanna',
#   'But me I was weirdly shy most of the time. Though a good sermon regarding Gods call to Samuel to serve him.'],
#  ['14/01/2018, 14:59',
#   'Joanna',
#   'Anyway no electricity let me spare the battery'],
#  ['14/01/2018, 15:00', 'Joanna', 'Thank you Juni'],
#  ['14/01/2018, 15:00', 'Anna Christine', 'Hhhahahaha hah. .. village!'],
#  ['14/01/2018, 15:01', 'Irene Nakalembe', 'I can’t'],
#  ['14/01/2018, 19:21', 'Kate', 'Happy anniversary to Mr. and Mrs Kibuuka.'],
#  ['14/01/2018, 19:48', None, 'Tina, Kerbi: <Media omitted>'],
#  ['14/01/2018, 19:48', None, 'Tina, Kerbi: <Media omitted>'],
#  ['14/01/2018, 20:19', 'Beth', '<Media omitted>'],
#  ['14/01/2018, 20:26', 'Beth', '<Media omitted>'],
#  ['15/01/2018, 08:21', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['15/01/2018, 17:50', 'TJ Musiitwa', '<Media omitted>'],
#  ['15/01/2018, 18:43',
#   None,
#   'Tina, Kerbi: MR AND MRS. MUBANGIZI MEMORIAL MASS (THE LATE)'],
#  ['15/01/2018, 18:49',
#   None,
#   'Tina, Kerbi: Kindly let other friends and relatives know...'],
#  ['15/01/2018, 18:50', '+256 792 754083', '👏🏻👏🏻👏🏻'],
#  ['15/01/2018, 19:22', 'Fina', 'May he continue to rest in peace.'],
#  ['15/01/2018, 19:22',
#   'Irene Nakalembe',
#   'May they continue to rest in Peace!'],
#  ['15/01/2018, 19:23', 'Fina', 'May aunty Anna continue to rest in peace'],
#  ['15/01/2018, 19:53', 'Elsie Mulo', 'May they continue to Rest in Peace.'],
#  ['15/01/2018, 21:00', 'Anna Christine', 'May they continue to rest in peace'],
#  ['16/01/2018, 02:54', 'Aunt Dora', '<Media omitted>'],
#  ['16/01/2018, 22:41', 'Aunt Dora', '<Media omitted>'],
#  ['17/01/2018, 08:49',
#   'Aunt Dora',
#   'Thanks so much for this gift. May God rest their souls in peace 🙏🏽🙏🏽'],
#  ['17/01/2018, 11:23', '+256 792 754083', '<Media omitted>'],
#  ['17/01/2018, 17:34',
#   None,
#   "Tina, Kerbi: Guys... Kindly help me pass on the invitation to all your parents... Don't have some of their numbers.  Your help is appreciated. Thank you"],
#  ['17/01/2018, 18:53', 'Aunt Dora', '<Media omitted>'],
#  ['17/01/2018, 18:53', 'Aunt Dora', '<Media omitted>'],
#  ['17/01/2018, 18:53', 'Aunt Dora', '<Media omitted>'],
#  ['17/01/2018, 19:30', 'Fina', '<Media omitted>'],
#  ['17/01/2018, 19:37', 'Aunt Dora', '<Media omitted>'],
#  ['17/01/2018, 19:49', 'Aunt Dora', '<Media omitted>'],
#  ['17/01/2018, 22:31', 'John Thomas', '*I LIVE IN A SHITHOLE*'],
#  ['18/01/2018, 03:45', 'Aunt Dora', '<Media omitted>'],
#  ['18/01/2018, 06:16', 'Anna Christine', '👏👏👏👏👏👏'],
#  ['18/01/2018, 06:33',
#   'Patsy',
#   'If you have received Pictures of Donald Trump suffering from a  stroke, please do not open it but  delete it immediately because it will destroy all info in your computer & handphone. Please pass this to all your friends & groups.'],
#  ['18/01/2018, 14:55', 'Beth', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:01', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:02', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:02', '+256 792 754083', '<Media omitted>'],
#  ['18/01/2018, 17:02',
#   '+256 792 754083',
#   'Thanks to you all 🙏🙏🙏 God bless you'],
#  ['18/01/2018, 17:21',
#   'Beth',
#   'Thank you all who made it. May their souls continue to rest in eternal peace.'],
#  ['18/01/2018, 17:37',
#   'Anna Christine',
#   "Thank you for representing fam. Very sorry I couldn't make it."],
#  ['18/01/2018, 18:09', None, 'Tina, Kerbi: <Media omitted>'],
#  ['18/01/2018, 18:42',
#   'Joanna',
#   'Thanks for making it. Apologies for not making it but we continue to pray for them, for the love they showered us, for the foresightedness they had, for their goodness joy and happiness they shared with us, we appreciate and celebrate them while praising the Lord for allowing us to experience their presence. May their souls rest in peace Amen.'],
#  ['18/01/2018, 18:52', 'Patsy', '🙏🏽Amen'],
#  ['18/01/2018, 18:55', 'Anna Christine', 'Amen!'],
#  ['18/01/2018, 19:14', 'Elsie Mulo', 'Amen!'],
#  ['18/01/2018, 19:17', 'Micheal', 'Amen... apologies for not making it'],
#  ['18/01/2018, 21:04',
#   'Aunt Dora',
#   'Thanks a trillion my lovely Tonny. Blessings to you all my dears for the great offer of mass for the loved ones.'],
#  ['19/01/2018, 12:51', 'Pauline', '<Media omitted>'],
#  ['19/01/2018, 12:53', 'Lena', '🤣🤣🤣🤣🤣🤣  i mean!'],
#  ['19/01/2018, 12:59', 'Elsie Mulo', '😏😏'],
#  ['19/01/2018, 12:59', 'Elsie Mulo', 'i like'],
#  ['19/01/2018, 13:04', 'Ben', '<Media omitted>'],
#  ['19/01/2018, 13:05', 'Ben', 'How I head to work on a Friday'],
#  ['19/01/2018, 13:06', 'Anna Christine', '😂😂😂😂😃 u and I both'],
#  ['19/01/2018, 13:10', 'Lena', '🤣🤣🤣🤣🤣🤣🤣🤣'],
#  ['19/01/2018, 13:11',
#   '+44 7525 475883',
#   "Its such a good feeling! But please forgive me if I'll not take a lift from you on Friday morning."],
#  ['19/01/2018, 13:12',
#   '+44 7525 475883',
#   '(Especially if I have to sit in the passenger seat)'],
#  ['19/01/2018, 13:12',
#   'Lena',
#   'Friday morning and then there is saturday evenings'],
#  ['19/01/2018, 13:13', 'Beth', 'Naye gha who are u pulling like that'],
#  ['19/01/2018, 13:17', 'Lena', 'Olivia Kay'],
#  ['19/01/2018, 13:20', 'Beth', '😂😂🤣🤣🤣 olivia u are deaddo'],
#  ['19/01/2018, 13:47',
#   'Anna Christine',
#   'Hehhehehehehe Solomon...to the back seat it will be'],
#  ['19/01/2018, 14:10', 'Pauline', '@Ben...this is how you drive everyday 😫'],
#  ['19/01/2018, 14:15',
#   'Anna Christine',
#   'Hahahhahahaha. .. I kid u not. No denying this one Ben...ok except for mkmday morning'],
#  ['19/01/2018, 14:15',
#   'Lawrence Kibuuka',
#   'Bwahahahahhahahahahahhahahahahahahahahahahahahahahahahahahahahahhahahahahahahahahaahahaha 😂😂😂😂😂This jst cracked me up'],
#  ['19/01/2018, 14:56', 'Fina', 'Eh poor passengers.... Ben ngaha'],
#  ['19/01/2018, 15:55',
#   'Ben',
#   "You know it ... .. as long as the chuuuuuine comes up ... don't be in that passenger seat .."],
#  ['19/01/2018, 17:50', 'Beth', '<Media omitted>'],
#  ['19/01/2018, 17:52', 'Beth', '<Media omitted>'],
#  ['19/01/2018, 18:38', 'Micheal', 'Gayaza hug👆🏼👆🏼👆🏼'],
#  ['19/01/2018, 21:09',
#   'Aunt Dora',
#   "There is a Whatsap group called' *Interschools*. If invited, don't join the group. It belongs to Daesh(ISIS). If you join the group you will not be able to exit from it.  Be vigilant. Please inform others. My dear send it to your relatives and children on Whatsap so that they will also be careful."],
#  ['19/01/2018, 21:14',
#   'Aunt Dora',
#   'A CERTAIN GIRL IN MASAKA HAS BEEN ATTACKED BY HER CLAN GHOSTS ON HER WEDDING DAY WHICH LEFT HER UNDRESSED.'],
#  ['19/01/2018, 21:14', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:15', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:15', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:16', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:16', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:16', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:16', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:16', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:16', 'Aunt Dora', '<Media omitted>'],
#  ['19/01/2018, 21:22',
#   'Fina',
#   'Those pictures are actually from a movie.... not real life'],
#  ['19/01/2018, 22:11',
#   None,
#   'Tina, Kerbi: Lol... Do u seee how serious the camera guys are?! 😱'],
#  ['20/01/2018, 04:21', 'Aunt Dora', '<Media omitted>'],
#  ['20/01/2018, 09:30',
#   'Kate',
#   'Do you know any vulnarable child who have passed his/her P.L.E with 4-12? or he/she might be a continuing student of S2-S4 Who passes with (8-12)in 8, Youth league Africa  has a full bursary scheme for them in best schools around Kampala. S5 and S6 packages are coming very soon. Contact us on +256705461970, or 0775637678. Please Dont sit in this Message, share it untill it reaches to the person in need. Thanks'],
#  ['20/01/2018, 13:22', 'John Thomas', '<Media omitted>'],
#  ['20/01/2018, 13:34', None, 'Tina, Kerbi: Otyo...'],
#  ['20/01/2018, 14:56', 'John Thomas', '<Media omitted>'],
#  ['20/01/2018, 14:57', 'Pauline', '🤣'],
#  ['20/01/2018, 15:00', None, 'Tina, Kerbi: Kijja kugwa....'],
#  ['20/01/2018, 15:53', 'John Thomas', '<Media omitted>'],
#  ['20/01/2018, 18:31', 'John Thomas', '<Media omitted>'],
#  ['21/01/2018, 11:03', 'John Thomas', 'WHISPER OF HOPE DEVOTIONAL'],
#  ['21/01/2018, 19:13', 'Aunt Dora', 'Ooh good, it was ekina Uganda film 👇🏾'],
#  ['21/01/2018, 19:13', 'Aunt Dora', '<Media omitted>'],
#  ['21/01/2018, 19:16', 'Aunt Dora', '<Media omitted>'],
#  ['21/01/2018, 19:16', 'Anna Christine', '😂😂😂😂😂'],
#  ['21/01/2018, 19:29', 'Aunt Dora', '<Media omitted>'],
#  ['21/01/2018, 20:51', 'Beth', '<Media omitted>'],
#  ['21/01/2018, 21:08', 'John Thomas', '<Media omitted>'],
#  ['21/01/2018, 21:08', 'John Thomas', '<Media omitted>'],
#  ['21/01/2018, 21:25', 'John Thomas', '<Media omitted>'],
#  ['21/01/2018, 21:27',
#   '+1 (647) 704-2525',
#   'Banange John! Your pictures occupy half my phone memory'],
#  ['21/01/2018, 21:28', 'John Thomas', 'Get a bigger phone'],
#  ['21/01/2018, 21:28',
#   'Ben',
#   'Buy a phone with bigger memory capacity ..totukuba naku yo...'],
#  ['21/01/2018, 21:29', '+1 (647) 704-2525', 'Bring the money'],
#  ['21/01/2018, 21:29',
#   '+1 (647) 704-2525',
#   'I can’t spend my Sunday deleting repeated pictures'],
#  ['21/01/2018, 21:29', '+1 (647) 704-2525', '<Media omitted>'],
#  ['21/01/2018, 21:32',
#   'TJ Musiitwa',
#   'This is where I sorta miss the windows phone...allowed me to avoid media downloads per chat.....'],
#  ['21/01/2018, 21:33', 'Ben', '<Media omitted>'],
#  ['21/01/2018, 21:33', 'Joanna', "Oba why don't you listen?"],
#  ['21/01/2018, 21:36', 'John Thomas', "Oba why don't you let it go"],
#  ['21/01/2018, 21:37',
#   'Joanna',
#   'Consider your friends and relatives and not send pictures and videos'],
#  ['21/01/2018, 21:37', '+1 (647) 704-2525', '!!!!'],
#  ['21/01/2018, 21:37', 'John Thomas', 'Is this directed to me'],
#  ['21/01/2018, 21:37', 'Joanna', 'Gone'],
#  ['22/01/2018, 05:41',
#   'Aunt Dora',
#   '"Entamu yo ewunzikibwa leero" a Luganda word literally meaning that \'You are dying today\' said the two men disguised as electricty subcontractor workers as they tried to slit the throat of a defenceless 51-year-old woman in Jjanda Namugongo Zone, Kira Municipality Wakiso District.'],
#  ['22/01/2018, 05:41', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:41', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:41', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:41', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:41', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 05:42', 'Aunt Dora', '<Media omitted>'],
#  ['22/01/2018, 08:40',
#   'Ben',
#   '@16178173376,@256759071143 we going back to the promised land ... on the back of the G.O.A.T... #letsgoPATS'],
#  ['22/01/2018, 08:41', 'Irene Nakalembe', '😂😂😂😂😂lets go'],
#  ['22/01/2018, 08:54', 'Anna Christine', 'Woop woop!'],
#  ['23/01/2018, 02:51', 'Aunt Dora', '<Media omitted>'],
#  ['23/01/2018, 03:05',
#   'Aunt Dora',
#   '*Whatever comes your way as you journey into this New Year, remember the lesson of this story...*👇'],
#  ['23/01/2018, 07:28', 'Fina', 'Clever boy'],
#  ['23/01/2018, 07:30', 'Patsy', 'smart indeed'],
#  ['23/01/2018, 07:31', 'Ben', '<Media omitted>'],
#  ['23/01/2018, 20:54', 'Aunt Dora', '*UBUNTU* ! *UBUNTU* !! *UBUNTU* !!!'],
#  ['23/01/2018, 20:54', 'Aunt Dora', '<Media omitted>'],
#  ['23/01/2018, 21:26', 'Beth', '<Media omitted>'],
#  ['23/01/2018, 21:29',
#   'John Thomas',
#   "Mpozi what's the dstv call center number"],
#  ['23/01/2018, 21:48',
#   None,
#   'Tina, Kerbi: Lool! Hw I wish I CD be that real😂😂😂😂😅😅..'],
#  ['23/01/2018, 21:54', 'Fina', 'Hehehe. Runs off Facebook'],
#  ['23/01/2018, 23:05', 'Aunt Dora', '<Media omitted>'],
#  ['24/01/2018, 00:20', 'Aunt Dora', '<Media omitted>'],
#  ['24/01/2018, 00:21',
#   'Aunt Dora',
#   '👆🏾 I am meant to understand that it’s Boda B 2020'],
#  ['24/01/2018, 01:48',
#   'Joanna',
#   'So today was my last day at area code 7131 to 70'],
#  ['24/01/2018, 06:59', None, 'Tina, Kerbi: Conga dear....'],
#  ['24/01/2018, 06:59', None, 'Tina, Kerbi: *congs'],
#  ['24/01/2018, 07:07', 'Joanna', 'Thank you.'],
#  ['24/01/2018, 07:37', 'Patsy', 'pardon?'],
#  ['24/01/2018, 08:16', 'Aunt Dora', '<Media omitted>'],
#  ['24/01/2018, 08:32',
#   'Kate',
#   'God speed Joana. May the Lord prosper you in your new place.'],
#  ['24/01/2018, 08:36',
#   'Anna Christine',
#   'Sibitegedde....but since everyone is saying congs. ...congratulations joanna'],
#  ['24/01/2018, 08:42', 'Joanna', 'Amen. Thank you Kate'],
#  ['24/01/2018, 08:43', 'Joanna', '😆 Thank you Anna'],
#  ['24/01/2018, 08:44',
#   'Joanna',
#   "I've left Pauline's place and moved back to my ex🙈"],
#  ['24/01/2018, 08:46', 'Joanna', 'This message was deleted'],
#  ['24/01/2018, 08:46', 'Joanna', 'This message was deleted'],
#  ['24/01/2018, 08:46', '+256 792 754083', 'Change what you drink 🍹😂😂😂'],
#  ['24/01/2018, 08:47', 'Joanna', 'Lol... I did 🍶🍵'],
#  ['24/01/2018, 08:53',
#   'Joanna',
#   "That radio story isn't true the guy is till alive"],
#  ['24/01/2018, 08:58', 'Anthony Busulwa', 'Congratulations Joanna'],
#  ['24/01/2018, 09:06', 'Joanna', 'Thank you Tony'],
#  ['24/01/2018, 09:16',
#   'Aunt Dora',
#   'Congs Joan. Abundant blessings in the new my dear'],
#  ['24/01/2018, 09:20', 'Joanna', 'Amen thank you Ma.'],
#  ['24/01/2018, 09:37', 'Patsy', 'me toooo am confused also'],
#  ['24/01/2018, 09:55', 'Elsie Mulo', 'congratulations Joanna'],
#  ['24/01/2018, 10:29', 'Irene Nakalembe', 'Congrats Joanna'],
#  ['24/01/2018, 10:41',
#   'Fina',
#   'Enjoy your new are code and job at standard chartered bank. Keep growing, rising and prospering'],
#  ['24/01/2018, 11:05', 'Joanna', 'Hehe thank you'],
#  ['24/01/2018, 11:06', 'Joanna', '@dfcu'],
#  ['24/01/2018, 11:07',
#   'Fina',
#   'Kati is it dfcu or standard chartered. Our best regards,  congratulatory messages and blessings are floating around kla😁'],
#  ['24/01/2018, 11:12', 'Lena', 'congratulations Joana!'],
#  ['24/01/2018, 11:25', 'Joanna', "Thank so much. It's DFCU"],
#  ['24/01/2018, 11:26', 'Joanna', 'Thank you Lena'],
#  ['24/01/2018, 11:26', 'Joanna', 'Thank you Irene'],
#  ['24/01/2018, 11:26', 'Joanna', 'Thank you Elsie'],
#  ['24/01/2018, 11:41',
#   '+44 7525 475883',
#   'Kulika nnyo! Era weebale kubeera kyamuwendo eri bakama bo. Tukwagaliza bilungi byereere mu buvunanyizibwa obupya.'],
#  ['24/01/2018, 11:48', 'Fina', '👏🏾👏🏾👏🏾👏🏾👏🏾👏🏾'],
#  ['24/01/2018, 11:49',
#   'Fina',
#   'Kyoka you have been with Pauline, dah. ... baby brains, my bad'],
#  ['24/01/2018, 11:59', 'Pauline', 'Otyo'],
#  ['24/01/2018, 12:00',
#   'Lena',
#   'the things i pick up on, just to ease my mind, peathe explain the "baby brains"'],
#  ['24/01/2018, 12:00', 'Lena', "yeah! i knew you weren't far"],
#  ['24/01/2018, 12:19', 'Fina', '<Media omitted>'],
#  ['24/01/2018, 12:19',
#   'Joanna',
#   'Neyanziza nnyo Ssebo. Nkulaba! Oluganda lwo ndukonedde mu!👊🏽'],
#  ['24/01/2018, 12:20', 'Joanna', 'Baby brains means that Jose was being slow'],
#  ['24/01/2018, 14:08', '+1 (647) 704-2525', 'congratulations Joanna😊'],
#  ['24/01/2018, 14:21', 'Joanna', 'Thanks Adela'],
#  ['24/01/2018, 15:41', None, 'Tina, Kerbi: <Media omitted>'],
#  ['24/01/2018, 16:02',
#   'Beth',
# ...
#  ['06/02/2018, 10:42', 'Anna Christine', 'Ehhh I tell you'],
#  ['06/02/2018, 10:43', 'Anna Christine', 'Oooohhh ooohhhh!'],
#  ['06/02/2018, 10:52', 'Joanna', 'Smooth operator nanti is the result'],
#  ['06/02/2018, 10:58', 'Anna Christine', 'Hhehehheheh. ...'],
#  ['06/02/2018, 11:00', 'Fina', 'Why he was beaten...product is legit 😁'],
#  ['06/02/2018, 11:01', 'Fina', 'Looking good bruh'],
#  ['06/02/2018, 11:01',
#   'Anna Christine',
#   'Aaa.....Ben I think she deserves a bonquet of flowers for helping u blossom!'],
#  ['06/02/2018, 11:03', 'Micheal', '🤔'],
#  ['06/02/2018, 11:07',
#   'Anna Christine',
#   '😂😂😂😂😂 with a note " mummy webale emboko" hahhahahah'],
#  ['06/02/2018, 11:10',
#   'Ben',
#   'I deny the allegations of smooth operator ... but sometimes we do clean up nice'],
#  ['06/02/2018, 11:12',
#   'Ben',
#   "The kracken was beaten into submission I must admit ...no flowers that day hun ... it's Ash Wednesday ...am fasting meaning no biting flowers , choclate or wine ... church rules"],
#  ['06/02/2018, 11:15',
#   'Anna Christine',
#   'Hahhahhahaha aha. ... saved by the ashes once again'],
#  ['06/02/2018, 11:19', None, 'Tina, Kerbi: Lol... 😅'],
#  ['06/02/2018, 11:28', None, 'Tina, Kerbi: <Media omitted>'],
#  ['06/02/2018, 11:29', None, 'Tina, Kerbi: Popo... Take  the challenge ☝🏽'],
#  ['06/02/2018, 12:05', 'John Thomas', '<Media omitted>'],
#  ['06/02/2018, 12:06', 'John Thomas', 'Specially for mama D Joan and Anna'],
#  ['06/02/2018, 12:58', 'Joanna', 'Thank you'],
#  ['06/02/2018, 13:03', 'Anna Christine', 'OMG....how refreshing...musangawa?'],
#  ['06/02/2018, 15:54', None, 'Tina, Kerbi: <Media omitted>'],
#  ['06/02/2018, 21:07',
#   'Aunt Dora',
#   'Prayer for Finances  (it works)  I claimed it for you now claim it for me.  God has more than a thousand ways to provide for us, that we know nothing about.  Here is your financial Blessing!'],
#  ['06/02/2018, 21:13', None, 'Tina, Kerbi: Amen...'],
#  ['06/02/2018, 21:38', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:38', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:39', 'Aunt Dora', '<Media omitted>'],
#  ['06/02/2018, 21:42', 'Aunt Dora', '<Media omitted>'],
#  ['07/02/2018, 08:19', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['07/02/2018, 09:19', 'John Thomas', 'Lol'],
#  ['07/02/2018, 09:50', 'John Thomas', '*For the wheat lovers!!\u200b*'],
#  ['07/02/2018, 20:55', None, 'Tina, Kerbi: List of TOP schools in UCE 2017'],
#  ['07/02/2018, 21:25',
#   'Aunt Dora',
#   'An old church in a village in Brazil was leaking and the walls were almost collapsing, after the service the Padre asked the worshipers if they could organize a fundraising to rebuild the church... He told them to contribute whatever God has blessed each and everyone of them with. If you have some money, you can bring the money,if you earn a living by selling tomatoes in the market, you can bring the tomatoes and they get auctioned to raise the money... If you operate a hardware it would be even better, you can bring some nails and iron sheets for the roof... whatever you have. Eventually, it was the day of fundraising and worshippers came out in large numbers, some with money in their pockets others with goods depending on their jobs and sources of livelihood... They were met by a strange sight; a coffin at the entrance of the church!...Gosh! Who had died?... but then again it was on a Sunday and funeral services were never conducted on Sundays.... What was going on? People started talking in whispers asking what was the meaning of it...they started pointing fingers to an old man seated at a corner; he was the coffin maker...some looked at him in open hostility, but he didn\'t mind them... the Padre had said that people should bring whatever God has blessed you with, right?... and he was a coffin maker... After the service it was time to raise funds ; those who had money contributed, hardware people gave iron sheets and other building equipments and materials ,tomatoes\' traders had brought their tomatoes which were auctioned away... Finally, the coffin maker dragged his coffin to the front of the church and stood still... people gasped and fell silent... you could hear a pin drop . Suddenly an old man, a friend of the coffin maker stood up....he offered 15,000 for the coffin on behalf of the padre... said he was buying it for the padre... The Padre shot up so fast with eyes wide open....his lips suddenly very dry. He quickly offered 20,000 for the coffin on behalf of the leader of CWA (Catholic women Association) The Lady nearly stumbled as she sprang to her feet looking so shocked at seeing her coffin..." No! no! no!" She shouted "it is not mine! ...i ...i...i...will buy it for the Catechist!... 30,000 please!... please! The Catechist nearly peed on himself he turned to look at her angrily as if to ask " do you want to kill me?!" Clearly nobody wanted the coffin and it kept on being passed around until finally another old rich man stood and said that, he is offering 100,000 for the coffin and he is buying it on behalf of the coffin maker... The coffin maker took his coffin and returned it to his shop....smiling. The coffin maker; someone who was looked down upon, someone whom people jeered that he benefits from the misfortunes of others raised the greatest amount of money for the church without contributing even a single coin. You can serve God in many different ways. Perhaps people belittle you until you see yourself as a nobody.....but God want you just the way you are. He will turn your shame into honor.'],
#  ['07/02/2018, 22:19', 'John Thomas', 'Kiseka... A bus has run over people.'],
#  ['07/02/2018, 22:19', 'John Thomas', '<Media omitted>'],
#  ['07/02/2018, 22:21',
#   'Aunt Dora',
#   'I found this somewhere and it made me think,'],
#  ['07/02/2018, 23:19', None, 'Tina, Kerbi: Be with you too'],
#  ['08/02/2018, 08:54', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 11:28', 'Lena', 'Happy birthday Karen!!'],
#  ['08/02/2018, 11:34', 'Elsie Mulo', 'Happy Birthday Karen 🤗🤗'],
#  ['08/02/2018, 11:45', 'Anthony Busulwa', 'Happy Birthday Karen'],
#  ['08/02/2018, 11:48', '+256 795 230837', 'Yes'],
#  ['08/02/2018, 14:32', 'Ben', '<Media omitted>'],
#  ['08/02/2018, 14:33',
#   'Ben',
#   'Can one of you guys order for me priiiiz ...valentines is back on ... #willingtorisklent'],
#  ['08/02/2018, 15:26', '+1 (647) 704-2525', 'Happy Birthday Karen 🤗'],
#  ['08/02/2018, 15:28', 'Fina', 'Happy birthday Karen'],
#  ['08/02/2018, 15:29', '+256 795 230837', 'Thanx Ade'],
#  ['08/02/2018, 15:30', '+256 795 230837', 'Thank u'],
#  ['08/02/2018, 15:45', 'Anna Christine', 'Happy birthday Karen!'],
#  ['08/02/2018, 17:40', '+256 795 230837', 'Thanks'],
#  ['08/02/2018, 17:41', '+256 795 230837', 'Thank u'],
#  ['08/02/2018, 17:41', '+256 795 230837', 'Thanx'],
#  ['08/02/2018, 17:41', '+256 795 230837', 'Thanx anna'],
#  ['08/02/2018, 19:12', 'Irene Nakalembe', 'Happy birthday Karen'],
#  ['08/02/2018, 19:13', 'Irene Nakalembe', 'Omusudan ajaa kukuba'],
#  ['08/02/2018, 20:00', 'Kate', 'Happy birthday Karen'],
#  ['08/02/2018, 20:04', 'Micheal', 'HBD Karen'],
#  ['08/02/2018, 20:16', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 20:17', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 20:18', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 20:19', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 20:19', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 20:19', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 20:19', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 21:24',
#   '+256 795 230837',
#   'Thank you all so much for the bd messages'],
#  ['08/02/2018, 21:33',
#   'Ben',
#   'Happy birthday Karen... blessings and bottle your way'],
#  ['08/02/2018, 21:46',
#   '+256 795 230837',
#   'Ohh Ben  thank you  so much  those bottles are making me type in 10D'],
#  ['08/02/2018, 21:46', '+256 795 230837', '🤣🤣🤣'],
#  ['08/02/2018, 22:55', 'Aunt Dora', 'We my need some very soon'],
#  ['08/02/2018, 22:55', 'Aunt Dora', '<Media omitted>'],
#  ['08/02/2018, 22:56', 'Aunt Dora', 'Sorry may'],
#  ['09/02/2018, 10:49', 'John Thomas', '<Media omitted>'],
#  ['09/02/2018, 15:30', 'John Thomas', 'This message was deleted'],
#  ['09/02/2018, 15:30', 'John Thomas', 'This message was deleted'],
#  ['09/02/2018, 15:30', 'John Thomas', 'This message was deleted'],
#  ['09/02/2018, 15:30', 'John Thomas', 'This message was deleted'],
#  ['09/02/2018, 15:31', None, 'Elsie Mulo left'],
#  ['09/02/2018, 15:32', None, '+1 (647) 704-2525 left'],
#  ['09/02/2018, 15:35', 'Ben', "John tom please don't send such pics bruv ..."],
#  ['09/02/2018, 15:36', 'Ben', "They aren't welcome on the page ..."],
#  ['09/02/2018, 15:36',
#   'Ben',
#   "Kindly delete for those who haven't downloaded yet"],
#  ['09/02/2018, 15:40', None, 'Joanna added Elsie Mulo and +1 (647) 704-2525'],
#  ['09/02/2018, 15:40', 'Joanna', 'Pics have been deleted.'],
#  ['09/02/2018, 15:43',
#   'Elsie Mulo',
#   "it's annoying being in a group where someone is so inconsiderate. we have asked countless times not to be sent useless visuals on here but all in vain"],
#  ['09/02/2018, 15:44', None, 'John Thomas left'],
#  ['09/02/2018, 15:45',
#   'Ben',
#   'Lol now check ... Tina first correct my spelling ... ekiiri hannuya...'],
#  ['09/02/2018, 15:45', 'Ben', 'Am I correct ?'],
#  ['09/02/2018, 15:47', None, 'Joanna added John Thomas'],
#  ['09/02/2018, 15:48',
#   'Ben',
#   'Lol John you had gone into self imposed exile ...'],
#  ['09/02/2018, 15:49',
#   'Ben',
#   'Issa Friday chill... bruh ... I owe you a drink for that little one you brought'],
#  ['09/02/2018, 15:51', None, 'John Thomas left'],
#  ['09/02/2018, 16:02',
#   'Ben',
#   'lol John ... hahad ... Joan let him cool off first we shall come back for him later ...'],
#  ['09/02/2018, 22:55', 'Aunt Dora', '<Media omitted>'],
#  ['09/02/2018, 22:55', 'Aunt Dora', '<Media omitted>'],
#  ['09/02/2018, 23:03', 'Fina', "Ain't dead. But needs prayers"],
#  ['10/02/2018, 14:11',
#   None,
#   "Tina, Kerbi: On wife's birthday , man ordered a cake on the phone."],
#  ['11/02/2018, 15:12', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['11/02/2018, 15:43', 'Joanna', 'He knows how to chill'],
#  ['11/02/2018, 15:44', 'Joanna', "Neera muwereza hi 5! He's the bomb!"],
#  ['11/02/2018, 16:03', 'Fina', 'Great'],
#  ['11/02/2018, 23:02', None, 'Tina, Kerbi: <Media omitted>'],
#  ['12/02/2018, 10:51',
#   'Anthony Busulwa',
#   "From uncle Joseph. For anyone who doesn't know yet:"],
#  ['12/02/2018, 10:56', 'Anna Christine', 'This message was deleted'],
#  ['12/02/2018, 10:57', 'Kate', 'Nga kitalo'],
#  ['12/02/2018, 11:00', 'Fina', 'Nga kitalo nnyo'],
#  ['12/02/2018, 11:01',
#   'Elsie Mulo',
#   'kitalo nnyo bambi. May she Rest in Peace'],
#  ['12/02/2018, 11:08', 'Joanna', 'Bambi may her soul rest in peace Amen'],
#  ['12/02/2018, 19:03', 'Irene Nakalembe', 'May she Rest In Peace'],
#  ['12/02/2018, 19:33', 'Patsy', 'awumule mu Mirembe'],
#  ['12/02/2018, 20:08', 'Olivia Namulindwa', 'May her soul Rest in Peace.'],
#  ['12/02/2018, 22:04', '+1 (647) 704-2525', 'May she Rest In Peace'],
#  ['12/02/2018, 22:10', 'Aunt Dora', '<Media omitted>'],
#  ['13/02/2018, 00:46', 'Irene Nakalembe', 'Happy happy birthday Elsie😘😘😘'],
#  ['13/02/2018, 01:28', '+1 (647) 704-2525', 'Happy birthday sissy 😘😘'],
#  ['13/02/2018, 02:39',
#   '+44 7525 475883',
#   '🎂Happy birthday Elsie🎂. Enjoy your day, and I wish you happy days and great achievements.'],
#  ['13/02/2018, 05:50', 'Lena', 'Happy birthday Elsie!! 😘😘😘'],
#  ['13/02/2018, 06:22', 'Fina', 'Happy birthday El. Love you big big😘😘😘'],
#  ['13/02/2018, 06:40', 'Junior', 'Happy Birthday Elsie'],
#  ['13/02/2018, 06:59', 'Lawrence Kibuuka', 'Happy birthday day Elsie'],
#  ['13/02/2018, 07:29', 'Elsie Mulo', 'thanx hun🤗'],
#  ['13/02/2018, 07:29', 'Elsie Mulo', 'thanx lover'],
#  ['13/02/2018, 07:29', 'Elsie Mulo', 'thank you Solomon🤗'],
#  ['13/02/2018, 07:29', 'Elsie Mulo', 'thank you thank you 😘'],
#  ['13/02/2018, 07:29', 'Elsie Mulo', 'love you right back. thanx hun'],
#  ['13/02/2018, 07:29', 'Elsie Mulo', 'thanx Junior'],
#  ['13/02/2018, 07:30', 'Ben', 'Happy birthday love ... 😘'],
#  ['13/02/2018, 07:35', 'Elsie Mulo', 'thank you 🙂'],
#  ['13/02/2018, 07:35', 'Elsie Mulo', 'thank you hunneh'],
#  ['13/02/2018, 07:36', '+256 795 230837', 'Happy birthday  Elsie'],
#  ['13/02/2018, 07:37', 'Elsie Mulo', 'thank you Karen 🙂'],
#  ['13/02/2018, 07:39', 'Olivia Namulindwa', '🎉Happy Birthday Elsie! 🎉'],
#  ['13/02/2018, 07:41', 'Elsie Mulo', 'thanx hun'],
#  ['13/02/2018, 08:06', 'Anthony Busulwa', 'Happy Birthday Elsie.'],
#  ['13/02/2018, 08:22', 'Pauline', '🙄'],
#  ['13/02/2018, 08:22', 'Pauline', 'Happy Birthday Elsie🐣'],
#  ['13/02/2018, 08:24', 'Elsie Mulo', 'thank you Tony'],
#  ['13/02/2018, 08:24', 'Elsie Mulo', 'thanx bebe'],
#  ['13/02/2018, 08:28',
#   'Bengie',
#   'Happy birthday Elsie..Have an amazing one 😘'],
#  ['13/02/2018, 08:30', 'Elsie Mulo', 'thanx hun'],
#  ['13/02/2018, 08:31', 'Micheal', 'HBD L.C.'],
#  ['13/02/2018, 08:53',
#   'Kate',
#   'Happy birthday Elccy. 🤗🤗🤗🤗and more. May you enjoy all the details of life this year.'],
#  ['13/02/2018, 09:17', 'Elsie Mulo', 'thanx hun'],
#  ['13/02/2018, 09:18', 'Elsie Mulo', 'thank you lovely'],
#  ['13/02/2018, 09:22', 'Patsy', 'happy birthday awesome spirit'],
#  ['13/02/2018, 09:23', 'Elsie Mulo', 'thanx love 😘'],
#  ['13/02/2018, 09:49', 'Anna Christine', 'Happiest birthday Elsie!'],
#  ['13/02/2018, 09:58', 'Elsie Mulo', 'thanx hun'],
#  ['13/02/2018, 09:59', 'TJ Musiitwa', '<Media omitted>'],
#  ['13/02/2018, 10:01',
#   'Elsie Mulo',
#   'Jesus. can we ignore the "then" 😂😂ayayayayya'],
#  ['13/02/2018, 10:01',
#   'TJ Musiitwa',
#   "Hehe yeah I know can we....that was in the year of '12"],
#  ['13/02/2018, 10:12',
#   'Ben',
#   "Can see the cheeks 6 years ago... but Thomas why won't you let people prosper .."],
#  ['13/02/2018, 10:12', 'TJ Musiitwa', 'Prosper how??'],
#  ['13/02/2018, 10:41', 'Ben', '<Media omitted>'],
#  ['13/02/2018, 10:54',
#   'TJ Musiitwa',
#   'Haha this is what you are implying....??'],
#  ['13/02/2018, 10:55', 'Ben', 'Let Pauline answer for me ...'],
#  ['13/02/2018, 10:58', 'Pauline', 'E.P aka Enemy of Progress'],
#  ['13/02/2018, 10:59', 'TJ Musiitwa', '<Media omitted>'],
#  ['13/02/2018, 19:21', 'Lawrence Kibuuka', '<Media omitted>'],
#  ['13/02/2018, 21:19', 'Aunt Dora', '<Media omitted>'],
#  ['13/02/2018, 21:51',
#   'Aunt Dora',
#   "Something interesting regarding those who believe and those who don't believe in God! Very interesting. It stimulates our lateral thinking."],
#  ['13/02/2018, 21:55', 'Lawrence Kibuuka', 'well explained'],
#  ['13/02/2018, 21:59', None, 'Tina, Kerbi: Wow... Nuff sed!'],
#  ['13/02/2018, 22:09', 'Aunt Dora', '<Media omitted>'],
#  ['13/02/2018, 22:39', 'Anna Christine', 'Resounding!'],
#  ['13/02/2018, 23:18', 'Fina', 'I love it'],
#  ['14/02/2018, 08:22', 'Micheal', '<Media omitted>'],
#  ['14/02/2018, 08:23', 'Pauline', '🤣🤣🤣'],
#  ['14/02/2018, 08:23', 'Ben', 'You forgot to add mpiitaako ....'],
#  ['14/02/2018, 08:23', 'Pauline', '🚼'],
#  ['14/02/2018, 08:49', 'Micheal', '🤣🤣'],
#  ['14/02/2018, 09:03', 'Kate', 'Indeed. Best explanation. Im blessed by it.'],
#  ['14/02/2018, 17:54', 'Joanna', '<Media omitted>'],
#  ['15/02/2018, 00:50',
#   'Aunt Dora',
#   "Please, help share this post. This girl can't find her parents. She confessed that she was kidnapped by two men who later abandoned her on a lonely road after an argument. Let's help God in completing this miraculous work by making this child reach her parents again. She is not asking for your money or your gold, all she wants is for you to n share this post to different groups. SHARE and Share please to reach the parents of this child, if you have a heart don't ignore her."],
#  ['15/02/2018, 00:50', 'Aunt Dora', '<Media omitted>'],
#  ['15/02/2018, 00:54', 'Aunt Dora', '<Media omitted>'],
#  ...]

# %%
df=pd.DataFrame(parsedChat,columns=['DateTime','Author','Message'])

# %%
df.head()
# Out:
#             DateTime           Author  \
# 0               None             None
# 1  26/12/2017, 15:58           Joanna
# 2  26/12/2017, 22:45           Joanna
# 3  28/12/2017, 21:14          Micheal
# 4  28/12/2017, 21:39  +256 792 754083
#
#                                              Message
# 0  26/12/2017, 12:28 - Pauline: Lena and Pauline ...
# 1  Testing 3-5 outdoor venues by night today and ...
# 2                                    <Media omitted>
# 3                              It will happen to you
# 4                                       See yourself

# %%
df.tail()
# Out:
#                DateTime             Author                     Message
# 7329  25/12/2019, 12:40               Fina                  Beautiful.
# 7330  25/12/2019, 13:20             Joanna                Thank you😊🌹❤
# 7331  25/12/2019, 13:20             Joanna                          🤨🤔
# 7332  25/12/2019, 18:47  Olivia Namulindwa  Merry Christmas Family🎄🎁 💝
# 7333  26/12/2019, 16:58                Ben             <Media omitted>

# %%
df.describe()
# Out:
#                  DateTime  Author          Message
# count                7333    6882             7334
# unique               5662      35             4929
# top     15/12/2019, 08:10  Joanna  <Media omitted>
# freq                   26    1300             1604

# %%
# No. of images, images are represented by <Media omitted>
media=df[df['Message']=='<Media omitted>']

# %%
author_media_messages_value_counts=media['Author'].value_counts()
top10_author_media_messages_value_counts=author_media_messages_value_counts.head(10)

# %%
top10_author_media_messages_value_counts.plot.barh()
plot.ylabel('Author')
plot.xlabel('Media items sent')
plot.title('Most Media Items sent per Author')
# Out:
# Text(0.5, 1.0, 'Most Media Items sent per Author')

# %%
message_deleted=df[df['Message']=='This message was deleted']

# %%
message_deleted
# Out:
#                DateTime       Author                   Message
# 75    04/01/2018, 20:55         Lena  This message was deleted
# 600   24/01/2018, 08:46       Joanna  This message was deleted
# 601   24/01/2018, 08:46       Joanna  This message was deleted
# 679   01/02/2018, 12:03          Ben  This message was deleted
# 897   09/02/2018, 15:30  John Thomas  This message was deleted
# ...                 ...          ...                       ...
# 7104  18/12/2019, 15:54  John Thomas  This message was deleted
# 7149  20/12/2019, 12:12       Joanna  This message was deleted
# 7150  20/12/2019, 12:13       Joanna  This message was deleted
# 7153  21/12/2019, 08:23       Joanna  This message was deleted
# 7303  23/12/2019, 21:11       Joanna  This message was deleted
#
# [93 rows x 3 columns]

# %%
author_messages_deleted_value_counts=message_deleted['Author'].value_counts()

# %%
author_messages_deleted_value_counts
# Out:
# Author
# Joanna             45
# Lena                7
# Anna Christine      7
# John Thomas         6
# +256 792 754083     5
# Beth                5
# Ben                 3
# Irene Nakalembe     2
# Bengie              2
# Pauline             1
# Adela Mulo          1
# Junior              1
# Patsy               1
# Elsie Mulo          1
# Kate                1
# Kirijja Godfrey     1
# Micheal             1
# +44 7525 475883     1
# Livia Livie         1
# +256 776 584356     1
# Name: count, dtype: int64

# %%
top10_aithor_messages_deleted_value_counts=author_messages_deleted_value_counts.head(10)

# %%
import matplotlib.pyplot as plt
top10_aithor_messages_deleted_value_counts.plot.barh()
plt.ylabel('Author')
plt.xlabel('Message Deleted')
# Out:
# Text(0.5, 0, 'Message Deleted')

# %%
#Number of Group Notifications
grp_notif=df[df['Author']=='grp_notif']

# %%
grp_notif.shape
# Out:
# (0, 3)

# %%
# Drop the 'media omitted' messages,group notifications and deleted messages
df.drop(media.index,inplace=True)
df.drop(grp_notif.index,inplace=True)
df.drop(message_deleted.index,inplace=True)

# %%
# Find the null values
df.isnull().sum()
# Out:
# DateTime      1
# Author      452
# Message       0
# dtype: int64

# %%
# Drop empty rows
df=df.dropna()

# %%
df.shape
# Out:
# (5185, 3)

# %%
df.reset_index(inplace=True,drop=True)

# %% [markdown]
# Add the dateTime object from dateTime column

# %%
df['dateTime']=pd.to_datetime(df['DateTime'],infer_datetime_format=True)
# Out:
# /var/folders/xz/zhbbm3_x3xs8pc273mm25_580000gn/T/ipykernel_18608/2950886773.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['dateTime']=pd.to_datetime(df['DateTime'],infer_datetime_format=True)
# /var/folders/xz/zhbbm3_x3xs8pc273mm25_580000gn/T/ipykernel_18608/2950886773.py:1: UserWarning: Parsing dates in %d/%m/%Y, %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['dateTime']=pd.to_datetime(df['DateTime'],infer_datetime_format=True)

# %%
df['Day of Week']=pd.Series(pd.Categorical(df['dateTime'].dt.day_name(),categories=list(calendar.day_name)))

# %%
df['Day of Week']
# Out:
# 0         Tuesday
# 1        Thursday
# 2        Thursday
# 3        Thursday
# 4          Friday
#           ...
# 5180    Wednesday
# 5181    Wednesday
# 5182    Wednesday
# 5183    Wednesday
# 5184    Wednesday
# Name: Day of Week, Length: 5185, dtype: category
# Categories (7, object): ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
df['Hour']=pd.Series(pd.Categorical(df['dateTime'].dt.hour))

# %%
df['Hour']
# Out:
# 0       15
# 1       21
# 2       21
# 3       23
# 4       15
#         ..
# 5180    10
# 5181    12
# 5182    13
# 5183    13
# 5184    18
# Name: Hour, Length: 5185, dtype: category
# Categories (24, int32): [0, 1, 2, 3, ..., 20, 21, 22, 23]

# %%
df=df.set_index('dateTime')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5185 entries, 2017-12-26 15:58:00 to 2019-12-25 18:47:00
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DateTime     5185 non-null   object
#  1   Author       5185 non-null   object
#  2   Message      5185 non-null   object
#  3   Day of Week  5185 non-null   category
#  4   Hour         5185 non-null   category
# dtypes: category(2), object(3)
# memory usage: 173.0+ KB

# %%
df.head()
# Out:
#                               DateTime           Author  \
# dateTime
# 2017-12-26 15:58:00  26/12/2017, 15:58           Joanna
# 2017-12-28 21:14:00  28/12/2017, 21:14          Micheal
# 2017-12-28 21:39:00  28/12/2017, 21:39  +256 792 754083
# 2017-12-28 23:12:00  28/12/2017, 23:12             Beth
# 2017-12-29 15:36:00  29/12/2017, 15:36          Micheal
#
#                                                                Message  \
# dateTime
# 2017-12-26 15:58:00  Testing 3-5 outdoor venues by night today and ...
# 2017-12-28 21:14:00                              It will happen to you
# 2017-12-28 21:39:00                                       See yourself
# 2017-12-28 23:12:00  23/12/2017, 23:42:10 ‪+256 701 839948‬ BEWARE....
# 2017-12-29 15:36:00                                      Tina ng'okaye
#
#                     Day of Week Hour
# dateTime
# 2017-12-26 15:58:00     Tuesday   15
# 2017-12-28 21:14:00    Thursday   21
# 2017-12-28 21:39:00    Thursday   21
# 2017-12-28 23:12:00    Thursday   23
# 2017-12-29 15:36:00      Friday   15

# %% [markdown]
# ## Data Exploration

# %%
df.describe()
# Out:
#                  DateTime  Author Message Day of Week  Hour
# count                5185    5185    5185        5185  5185
# unique               4309      35    4595           7    24
# top     02/11/2018, 07:49  Joanna    Amen      Sunday     9
# freq                    8    1007      35         983   460

# %%
author_value_counts=df['Author'].value_counts()
top10_talkers=author_value_counts.head(10)

# %%
top10_talkers
# Out:
# Author
# Joanna             1007
# Anna Christine      449
# Fina                368
# Lena                341
# Aunt Dora           285
# Kate                256
# Ben                 241
# Irene Nakalembe     227
# Elsie Mulo          225
# Patsy               194
# Name: count, dtype: int64

# %%
top10_talkers.plot.barh()
plt.xlabel('Number of words')
plt.ylabel('Authors')
plt.title('The top 10 Most Talkatie Persons')
# Out:
# Text(0.5, 1.0, 'The top 10 Most Talkatie Persons')

# %%
df
# Out:
#                               DateTime             Author  \
# dateTime
# 2017-12-26 15:58:00  26/12/2017, 15:58             Joanna
# 2017-12-28 21:14:00  28/12/2017, 21:14            Micheal
# 2017-12-28 21:39:00  28/12/2017, 21:39    +256 792 754083
# 2017-12-28 23:12:00  28/12/2017, 23:12               Beth
# 2017-12-29 15:36:00  29/12/2017, 15:36            Micheal
# ...                                ...                ...
# 2019-12-25 10:48:00  25/12/2019, 10:48     Anna Christine
# 2019-12-25 12:40:00  25/12/2019, 12:40               Fina
# 2019-12-25 13:20:00  25/12/2019, 13:20             Joanna
# 2019-12-25 13:20:00  25/12/2019, 13:20             Joanna
# 2019-12-25 18:47:00  25/12/2019, 18:47  Olivia Namulindwa
#
#                                                                Message  \
# dateTime
# 2017-12-26 15:58:00  Testing 3-5 outdoor venues by night today and ...
# 2017-12-28 21:14:00                              It will happen to you
# 2017-12-28 21:39:00                                       See yourself
# 2017-12-28 23:12:00  23/12/2017, 23:42:10 ‪+256 701 839948‬ BEWARE....
# 2017-12-29 15:36:00                                      Tina ng'okaye
# ...                                                                ...
# 2019-12-25 10:48:00  Wow....you should have printed this card earli...
# 2019-12-25 12:40:00                                         Beautiful.
# 2019-12-25 13:20:00                                       Thank you😊🌹❤
# 2019-12-25 13:20:00                                                 🤨🤔
# 2019-12-25 18:47:00                         Merry Christmas Family🎄🎁 💝
#
#                     Day of Week Hour
# dateTime
# 2017-12-26 15:58:00     Tuesday   15
# 2017-12-28 21:14:00    Thursday   21
# 2017-12-28 21:39:00    Thursday   21
# 2017-12-28 23:12:00    Thursday   23
# 2017-12-29 15:36:00      Friday   15
# ...                         ...  ...
# 2019-12-25 10:48:00   Wednesday   10
# 2019-12-25 12:40:00   Wednesday   12
# 2019-12-25 13:20:00   Wednesday   13
# 2019-12-25 13:20:00   Wednesday   13
# 2019-12-25 18:47:00   Wednesday   18
#
# [5185 rows x 5 columns]

# %%
df['Date']=df['DateTime'].apply(lambda t:t.split(',')[0])

# %%
df['Date']
# Out:
# dateTime
# 2017-12-26 15:58:00    26/12/2017
# 2017-12-28 21:14:00    28/12/2017
# 2017-12-28 21:39:00    28/12/2017
# 2017-12-28 23:12:00    28/12/2017
# 2017-12-29 15:36:00    29/12/2017
#                           ...
# 2019-12-25 10:48:00    25/12/2019
# 2019-12-25 12:40:00    25/12/2019
# 2019-12-25 13:20:00    25/12/2019
# 2019-12-25 13:20:00    25/12/2019
# 2019-12-25 18:47:00    25/12/2019
# Name: Date, Length: 5185, dtype: object

# %%
df.groupby('Date')['Message'].count().plot()
plt.ylabel('Number of messages')
# Out:
# Text(0, 0.5, 'Number of messages')

# %%
df['Time']=df['DateTime'].apply(lambda t: t.split(',')[1])

# %%
df['Time']
# Out:
# dateTime
# 2017-12-26 15:58:00     15:58
# 2017-12-28 21:14:00     21:14
# 2017-12-28 21:39:00     21:39
# 2017-12-28 23:12:00     23:12
# 2017-12-29 15:36:00     15:36
#                         ...
# 2019-12-25 10:48:00     10:48
# 2019-12-25 12:40:00     12:40
# 2019-12-25 13:20:00     13:20
# 2019-12-25 13:20:00     13:20
# 2019-12-25 18:47:00     18:47
# Name: Time, Length: 5185, dtype: object

# %%
df.groupby('Time')['Message'].count().plot()
plt.ylabel('Number of messages')
# Out:
# Text(0, 0.5, 'Number of messages')

# %%
df.groupby('Hour')['Message'].count().plot()
plt.ylabel('Number of messages')
# Out:
# /var/folders/xz/zhbbm3_x3xs8pc273mm25_580000gn/T/ipykernel_18608/227844248.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Hour')['Message'].count().plot()
# Text(0, 0.5, 'Number of messages')

# %%
df['Letter Count']=df['Message'].apply(lambda s: len(s))

# %%
df['Letter Count']
# Out:
# dateTime
# 2017-12-26 15:58:00    86
# 2017-12-28 21:14:00    21
# 2017-12-28 21:39:00    12
# 2017-12-28 23:12:00    67
# 2017-12-29 15:36:00    13
#                        ..
# 2019-12-25 10:48:00    79
# 2019-12-25 12:40:00    10
# 2019-12-25 13:20:00    12
# 2019-12-25 13:20:00     2
# 2019-12-25 18:47:00    26
# Name: Letter Count, Length: 5185, dtype: int64

# %%
len('asdas')
# Out:
# 5

# %%
df['Word Count']=df['Message'].apply(lambda s: len(s.split(' ')))

# %%
df['Word Count']
# Out:
# dateTime
# 2017-12-26 15:58:00    15
# 2017-12-28 21:14:00     5
# 2017-12-28 21:39:00     2
# 2017-12-28 23:12:00     7
# 2017-12-29 15:36:00     2
#                        ..
# 2019-12-25 10:48:00    13
# 2019-12-25 12:40:00     1
# 2019-12-25 13:20:00     2
# 2019-12-25 13:20:00     1
# 2019-12-25 18:47:00     4
# Name: Word Count, Length: 5185, dtype: int64

# %%
df['Message']
# Out:
# dateTime
# 2017-12-26 15:58:00    Testing 3-5 outdoor venues by night today and ...
# 2017-12-28 21:14:00                                It will happen to you
# 2017-12-28 21:39:00                                         See yourself
# 2017-12-28 23:12:00    23/12/2017, 23:42:10 ‪+256 701 839948‬ BEWARE....
# 2017-12-29 15:36:00                                        Tina ng'okaye
#                                              ...
# 2019-12-25 10:48:00    Wow....you should have printed this card earli...
# 2019-12-25 12:40:00                                           Beautiful.
# 2019-12-25 13:20:00                                         Thank you😊🌹❤
# 2019-12-25 13:20:00                                                   🤨🤔
# 2019-12-25 18:47:00                           Merry Christmas Family🎄🎁 💝
# Name: Message, Length: 5185, dtype: object

# %%
df
# Out:
#                               DateTime             Author  \
# dateTime
# 2017-12-26 15:58:00  26/12/2017, 15:58             Joanna
# 2017-12-28 21:14:00  28/12/2017, 21:14            Micheal
# 2017-12-28 21:39:00  28/12/2017, 21:39    +256 792 754083
# 2017-12-28 23:12:00  28/12/2017, 23:12               Beth
# 2017-12-29 15:36:00  29/12/2017, 15:36            Micheal
# ...                                ...                ...
# 2019-12-25 10:48:00  25/12/2019, 10:48     Anna Christine
# 2019-12-25 12:40:00  25/12/2019, 12:40               Fina
# 2019-12-25 13:20:00  25/12/2019, 13:20             Joanna
# 2019-12-25 13:20:00  25/12/2019, 13:20             Joanna
# 2019-12-25 18:47:00  25/12/2019, 18:47  Olivia Namulindwa
#
#                                                                Message  \
# dateTime
# 2017-12-26 15:58:00  Testing 3-5 outdoor venues by night today and ...
# 2017-12-28 21:14:00                              It will happen to you
# 2017-12-28 21:39:00                                       See yourself
# 2017-12-28 23:12:00  23/12/2017, 23:42:10 ‪+256 701 839948‬ BEWARE....
# 2017-12-29 15:36:00                                      Tina ng'okaye
# ...                                                                ...
# 2019-12-25 10:48:00  Wow....you should have printed this card earli...
# 2019-12-25 12:40:00                                         Beautiful.
# 2019-12-25 13:20:00                                       Thank you😊🌹❤
# 2019-12-25 13:20:00                                                 🤨🤔
# 2019-12-25 18:47:00                         Merry Christmas Family🎄🎁 💝
#
#                     Day of Week Hour        Date    Time  Letter Count  \
# dateTime
# 2017-12-26 15:58:00     Tuesday   15  26/12/2017   15:58            86
# 2017-12-28 21:14:00    Thursday   21  28/12/2017   21:14            21
# 2017-12-28 21:39:00    Thursday   21  28/12/2017   21:39            12
# 2017-12-28 23:12:00    Thursday   23  28/12/2017   23:12            67
# 2017-12-29 15:36:00      Friday   15  29/12/2017   15:36            13
# ...                         ...  ...         ...     ...           ...
# 2019-12-25 10:48:00   Wednesday   10  25/12/2019   10:48            79
# 2019-12-25 12:40:00   Wednesday   12  25/12/2019   12:40            10
# 2019-12-25 13:20:00   Wednesday   13  25/12/2019   13:20            12
# 2019-12-25 13:20:00   Wednesday   13  25/12/2019   13:20             2
# 2019-12-25 18:47:00   Wednesday   18  25/12/2019   18:47            26
#
#                      Word Count
# dateTime
# 2017-12-26 15:58:00          15
# 2017-12-28 21:14:00           5
# 2017-12-28 21:39:00           2
# 2017-12-28 23:12:00           7
# 2017-12-29 15:36:00           2
# ...                         ...
# 2019-12-25 10:48:00          13
# 2019-12-25 12:40:00           1
# 2019-12-25 13:20:00           2
# 2019-12-25 13:20:00           1
# 2019-12-25 18:47:00           4
#
# [5185 rows x 9 columns]

# %%
print('Total Letter Count in the group:'+str(df['Letter Count'].sum()))
# Out:
# Total Letter Count in the group:210965

# %%
print('Total Word Count in the group:'+str(df['Word Count'].sum()))
# Out:
# Total Word Count in the group:38057

# %% [markdown]
# What is the most common number of words in a message?

# %%
plt.figure(figsize=(20,4))
word_count_value_counts=df['Word Count'].value_counts()
top30_word_count=word_count_value_counts.head(30)
top30_word_count.plot.bar()
plt.xlabel('Word Count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
## Summary by user
users=df.groupby('Author')['Author'].count()

# %%
print(users)
# Out:
# Author
# +1 (647) 704-2525         74
# +256 776 584356           13
# +256 776 584356 left       1
# +256 779 228234           15
# +256 792 754083           50
# +256 795 230837           12
# +256 795 230837 left       1
# +44 7525 475883           89
# Adela Mulo                62
# Anna Christine           449
# Anthony Busulwa           20
# Aunt Dora                285
# Ben                      241
# Bengie                   110
# Beth                      64
# Elsie Mulo               225
# Eric Mulo                 10
# Fina                     368
# Irene Nakalembe          227
# Jane                      61
# Joanna                  1007
# John Thomas              154
# Julie Anna                38
# Junior                    41
# Kate                     256
# Kirijja Godfrey           36
# Lawrence Kibuuka          98
# Lena                     341
# Livia Livie               50
# Micheal                  172
# Olivia Namulindwa         80
# Patsy                    194
# Pauline                  185
# TJ Musiitwa              145
# Tony Mulo                 11
# Name: Author, dtype: int64

# %%
## Summary by user
msg=df.groupby('Author')['Message'].count()

# %%
print(msg)
# Out:
# Author
# +1 (647) 704-2525         74
# +256 776 584356           13
# +256 776 584356 left       1
# +256 779 228234           15
# +256 792 754083           50
# +256 795 230837           12
# +256 795 230837 left       1
# +44 7525 475883           89
# Adela Mulo                62
# Anna Christine           449
# Anthony Busulwa           20
# Aunt Dora                285
# Ben                      241
# Bengie                   110
# Beth                      64
# Elsie Mulo               225
# Eric Mulo                 10
# Fina                     368
# Irene Nakalembe          227
# Jane                      61
# Joanna                  1007
# John Thomas              154
# Julie Anna                38
# Junior                    41
# Kate                     256
# Kirijja Godfrey           36
# Lawrence Kibuuka          98
# Lena                     341
# Livia Livie               50
# Micheal                  172
# Olivia Namulindwa         80
# Patsy                    194
# Pauline                  185
# TJ Musiitwa              145
# Tony Mulo                 11
# Name: Message, dtype: int64

# %% [markdown]
# So who exactly writes the most letters?

# %%
total_letter_count_by_author=df[['Author','Letter Count']].groupby('Author').sum()

# %%
sorted_total_letter_count_by_author=total_letter_count_by_author.sort_values('Letter Count',ascending=False)
top10_sorted_total_letter_grouped_by_author=sorted_total_letter_count_by_author.head(10)

# %%
top10_sorted_total_letter_grouped_by_author.plot.barh()
plt.xlabel('Number of letters')
plt.ylabel('Authors')
# Out:
# Text(0, 0.5, 'Authors')

# %%
total_letter_count_by_author=df[['Author','Letter Count']].groupby('Author').sum()
sorted_total_letter_count_by_author=total_letter_count_by_author.sort_values('Letter Count',ascending=False)
sorted_total_letter_grouped_by_author=sorted_total_letter_count_by_author
sorted_total_letter_grouped_by_author.plot.barh()
plt.xlabel('Number of letters')
plt.ylabel('Authors')
# Out:
# Text(0, 0.5, 'Authors')

# %% [markdown]
# Most Common number of letter per message

# %%
plt.figure(figsize=(15,2))
letter_count_value_counts=df['Letter Count'].value_counts()
top30_letter_count_value_counts=letter_count_value_counts.head(30)
top30_letter_count_value_counts.plot.bar()
plt.xlabel('Letter Count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# When was the group most active?

# %%
df['Day of Week'].value_counts().plot.barh()
plt.xlabel('Number of Messages')
plt.ylabel('Day of the Week')
# Out:
# Text(0, 0.5, 'Day of the Week')

# %% [markdown]
# Any Particular dates?

# %%
df['Date'].value_counts().head(10).plot.barh()
plt.xlabel('Number of Messages')
plt.ylabel('Date')
# Out:
# Text(0, 0.5, 'Date')

# %% [markdown]
# The most active Hour

# %% [markdown]
# The most suitable time of day to get your message replied to

# %%
df['Hour'].value_counts().head(10).plot.barh() # Top 10 Times of the day at which the most number of messages sent
plt.xlabel('Number of Messages')
plt.ylabel('Hour')
# Out:
# Text(0, 0.5, 'Hour')

# %%
df['Hour']
# Out:
# dateTime
# 2017-12-26 15:58:00    15
# 2017-12-28 21:14:00    21
# 2017-12-28 21:39:00    21
# 2017-12-28 23:12:00    23
# 2017-12-29 15:36:00    15
#                        ..
# 2019-12-25 10:48:00    10
# 2019-12-25 12:40:00    12
# 2019-12-25 13:20:00    13
# 2019-12-25 13:20:00    13
# 2019-12-25 18:47:00    18
# Name: Hour, Length: 5185, dtype: category
# Categories (24, int32): [0, 1, 2, 3, ..., 20, 21, 22, 23]

# %%
df['Time'].value_counts().head(10).plot.barh() # Top 10 Times of the day at which the most number of messages sent
plt.xlabel('Number of Messages')
plt.ylabel('Time')
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# What are the most commonly used words?

# %%
common_words=''
for val in df['Message'].values:
    val=str(val)
    tokens=val.split()
    
    for i in range(len(tokens)):
        tokens[i]=tokens[i].lower()
    
    for words in tokens:
        common_words=common_words + words + ''
famcloud=WordCloud(width=800,height=800).generate(common_words)

plt.figure(figsize=(8,8))
plt.imshow(famcloud)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
#If you want to download the image, Run the cell
famcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
df['Author'].unique()
# Out:
# array(['Joanna', 'Micheal', '+256 792 754083', 'Beth', 'Aunt Dora',
#        'Kate', 'Anna Christine', 'TJ Musiitwa', 'Ben', 'Anthony Busulwa',
#        '+1 (647) 704-2525', 'Patsy', 'Irene Nakalembe', 'Lena',
#        'Olivia Namulindwa', 'Lawrence Kibuuka', 'Fina', 'Junior',
#        'Julie Anna', 'Elsie Mulo', 'Tony Mulo', 'Pauline', 'Livia Livie',
#        '+256 776 584356 left', 'Bengie', 'John Thomas', '+44 7525 475883',
#        '+256 795 230837', '+256 776 584356', 'Jane',
#        '+256 795 230837 left', 'Adela Mulo', 'Kirijja Godfrey',
#        'Eric Mulo', '+256 779 228234'], dtype=object)

# %% [markdown]
# Find out the group's top 20 emoji usage

# %%
import emoji
import re
from collections import Counter

# Initialize Counter to store emoji occurrences
emojiGrpCtr = Counter()

# Use correct emoji data source
emojis_list = emoji.EMOJI_DATA.keys()

# Compile regular expression for matching emojis
r = re.compile('|'.join(re.escape(p) for p in emojis_list))

# Iterate through rows in the DataFrame
for idx, row in df.iterrows():
    # Find all emojis in the 'Message' column
    emojis_found = r.findall(row['Message'])
    
    # Count the occurrences of each emoji
    for emoji_found in emojis_found:
        emojiGrpCtr[emoji_found] += 1

# Print the 20 most common emojis
for item in emojiGrpCtr.most_common(20):
    print(item[0] + ' - ' + str(item[1]))
# Out:
# 🤣 - 797
# 😂 - 627
# 🤗 - 466
# 😘 - 318
# 🏽 - 285
# ❤ - 219
# 😍 - 198
# 👏 - 163
# 🏾 - 131
# 🎉 - 103
# ♀ - 80
# 🙏 - 80
# 😊 - 73
# 🎂 - 66
# 🥰 - 61
# 💃 - 56
# 🏃 - 52
# 🤔 - 50
# 🏼 - 50
# 🥳 - 49

# %%
emojiGrp=pd.DataFrame.from_dict(emojiGrpCtr,orient='index').reset_index()

# %%
emojiGrp=emojiGrp.rename(columns={'index':'Emoji',0:'Count'})

# %%
emojiGrp.head()
# Out:
#   Emoji  Count
# 0     👀     16
# 1     🤙      5
# 2     😂    627
# 3     🎵      1
# 4     🎶      1

# %% [markdown]
# ## Sentiment Analysis

# %%
df['Polarity']=df['Message'].map(lambda text: TextBlob(text).sentiment.polarity)

# %% [markdown]
# Randomly select 5 reviews with the highest positive polarity score

# %%
print('5 random reviews with the highest positive sentiment polarity: \n ')
cl=df.loc[df['Polarity']==1,['Message']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# 5 random reviews with the highest positive sentiment polarity:
#
# Happy anniversary!!
# Happy Birthday Maama Dora!! 💝
# Awesome news Tom with u all the way
# Happy birthday Eric! ❤
# Happy Birthday Beth!!! 🎉🎉

# %% [markdown]
# Randomly select 5 reviews with the most neutral sentiment polarity score

# %%
print('5 reviews with the most neutral sentiment(zero) polarity: \n')
cl=df.loc[df['Polarity']==0,['Message']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# 5 reviews with the most neutral sentiment(zero) polarity:
#
# Thank you mama D
# ☝🏾Becky and Eddy on an outing in Canada!😎
# I'll be in town today I'll try to ask about UBA
# Thank you all
# Yay in

# %% [markdown]
# Randomly select 5 reviews with the most negative sentiment polarity score

# %%
print('5 reviews with the most negative polarity: \n')
cl=df.loc[df['Polarity']==-0.50,['Message']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# 5 reviews with the most negative polarity:
#
# it's quite sad.
# sorry 2 zeros
# Damn !!!! Sad sad
# Ba na-uganda bamanyi okukola fake news😜
# I think I responded to it up there. Ill handle registration

# %% [markdown]
# The distribution of review sentiment polarity score

# %%
plt.hist('Polarity',data=df)
# Out:
# (array([2.000e+00, 1.100e+01, 5.900e+01, 7.800e+01, 9.100e+01, 3.318e+03,
#         2.960e+02, 3.470e+02, 1.680e+02, 8.150e+02]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## The End

# %%
# Calculate sentiment categories
df['Sentiment'] = df['Polarity'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

# Count the occurrences of each sentiment
sentiment_counts = df['Sentiment'].value_counts()

# Calculate percentages
total_messages = df.shape[0]
sentiment_percentages = (sentiment_counts / total_messages) * 100

# Display the results
print("Sentiment Percentages:")
print(sentiment_percentages)

# Optional: Plotting the sentiment distribution
sentiment_percentages.plot(kind='bar', color=['gray', 'green', 'red'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment Type')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)
plt.show()
# Out:
# Sentiment Percentages:
# Sentiment
# Neutral     55.525554
# Positive    39.826422
# Negative     4.648023
# Name: count, dtype: float64

# %%
# Calculate the total number of messages
total_messages = df['Message'].count()
print(f'Total number of messages: {total_messages}')
# Out:
# Total number of messages: 5185
